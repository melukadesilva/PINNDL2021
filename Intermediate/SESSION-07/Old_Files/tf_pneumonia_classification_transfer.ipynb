# %%
#!pip install pandas
#!pip install tensorflow-gpu
#!pip install matplotlib
#!pip install sklearn

# %%
import re
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from tensorflow.keras.applications import vgg16
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator

tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
## Ref: https://www.tensorflow.org/guide/data_performance
AUTOTUNE = tf.data.experimental.AUTOTUNE ## Auto tune tf.data hyper parameters for 
## data loading performance
FILE_PATH = '/media/akaaku13m/af04068d-3c77-49e2-977e-15b2e7dd348e/research_assistance_work/courses/PINNDL/local/data/'
#GCS_PATH = KaggleDatasets().get_gcs_path()
BATCH_SIZE = 16 * 8#strategy.num_replicas_in_sync
IMAGE_SIZE = [180, 180]
EPOCHS = 25

# %% [markdown]
# # Data Preperation

# %%
filenames = tf.io.gfile.glob(str(FILE_PATH + '/chest_xray/train/*/*'))
filenames.extend(tf.io.gfile.glob(str(FILE_PATH + '/chest_xray/val/*/*')))

## since there are 16 images for the validation set, first both train and test sets are
## combined and then the dataset is split with 80, 20 rule (80% training, 20% testing)
train_filenames, val_filenames = train_test_split(filenames, test_size=0.2)

# %%
COUNT_NORMAL = len([filename for filename in train_filenames if "NORMAL" in filename])
print("Normal images count in training set: " + str(COUNT_NORMAL))

COUNT_PNEUMONIA = len([filename for filename in train_filenames if "PNEUMONIA" in filename])
print("Pneumonia images count in training set: " + str(COUNT_PNEUMONIA))
# Out:
# Normal images count in training set: 1075
# Pneumonia images count in training set: 3110

# %%
## put the file names in a tf tensor
train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

## view few of the file names
for f in train_list_ds.take(5):
    print(f.numpy())
# Out:
# b'/media/akaaku13m/af04068d-3c77-49e2-977e-15b2e7dd348e/research_assistance_work/courses/PINNDL/local/data//chest_xray/train/PNEUMONIA/person1030_virus_1722.jpeg'
# b'/media/akaaku13m/af04068d-3c77-49e2-977e-15b2e7dd348e/research_assistance_work/courses/PINNDL/local/data//chest_xray/train/PNEUMONIA/person768_virus_1396.jpeg'
# b'/media/akaaku13m/af04068d-3c77-49e2-977e-15b2e7dd348e/research_assistance_work/courses/PINNDL/local/data//chest_xray/train/PNEUMONIA/person370_bacteria_1692.jpeg'
# b'/media/akaaku13m/af04068d-3c77-49e2-977e-15b2e7dd348e/research_assistance_work/courses/PINNDL/local/data//chest_xray/train/PNEUMONIA/person1722_bacteria_4547.jpeg'
# b'/media/akaaku13m/af04068d-3c77-49e2-977e-15b2e7dd348e/research_assistance_work/courses/PINNDL/local/data//chest_xray/train/PNEUMONIA/person1273_bacteria_3234.jpeg'

# %%
## cardinality gives the number of unique elements in the dataset
## Ref: https://orangematter.solarwinds.com/2020/01/05/what-is-cardinality-in-a-database/
## Ref: https://www.tensorflow.org/api_docs/python/tf/data/experimental/cardinality
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print("Training images count: " + str(TRAIN_IMG_COUNT))

VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print("Validating images count: " + str(VAL_IMG_COUNT))
# Out:
# Training images count: 4185
# Validating images count: 1047

# %%
## View the two classes
CLASS_NAMES = np.array([str(tf.strings.split(item, os.path.sep)[-1].numpy())[2:-1]
                        for item in tf.io.gfile.glob(str(FILE_PATH + "/chest_xray/train/*"))])
CLASS_NAMES
# Out:
# array(['PNEUMONIA', 'NORMAL'], dtype='<U9')

# %%
## Returns 0 or 1 (False or True) labels
## 1 indicates the Pneumonia class and 0 indicates a Normal class
def get_label(file_path):
    # convert the path to a list of path components
    parts = tf.strings.split(file_path, os.path.sep)
    # The second to last is the class-directory
    return parts[-2] == "PNEUMONIA"

# %%
def decode_img(img):
  # convert the compressed string to a 3D uint8 tensor
  img = tf.image.decode_jpeg(img, channels=3)
  # Use `convert_image_dtype` to convert to floats in the [0,1] range.
  img = tf.image.convert_image_dtype(img, tf.float32)
  # resize the image to the desired size.
  return tf.image.resize(img, IMAGE_SIZE)

# %%
## from a given file path get the label and the corresponding image
def process_path(file_path):
    label = get_label(file_path)
    # load the raw data from the file as a string
    img = tf.io.read_file(file_path)
    img = decode_img(img)
    return img, label

# %%
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
print(AUTOTUNE)
# Out:
# -1

# %%
## check the new dataset
for image, label in train_ds.take(1):
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
# Out:
# Image shape:  (180, 180, 3)
# Label:  True

# %%
## Prepare a test dataset for validating the model performances after training
test_list_ds = tf.data.Dataset.list_files(str(FILE_PATH + '/chest_xray/test/*/*'))
TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

TEST_IMAGE_COUNT
# Out:
# 624

# %%
## For caching, repeat, and prefetch, please refer to
## Ref: https://www.tensorflow.org/api_docs/python/tf/data/Dataset
def prepare_for_training(ds, cache=True, shuffle_buffer_size=1000):
    # This is a small dataset, only load it once, and keep it in memory.
    # use `.cache(filename)` to cache preprocessing work for datasets that don't
    # fit in memory.
    if cache:
        if isinstance(cache, str): ## if caching to a file
            ds = ds.cache(cache)
        else: ## cache in memory
            ds = ds.cache()
    ## shuffle data, otherwise, data will be cached with the same patten (not random)
    ds = ds.shuffle(buffer_size=shuffle_buffer_size)

    # Repeat forever
    ds = ds.repeat()

    ds = ds.batch(BATCH_SIZE)

    # `prefetch` lets the dataset fetch batches in the background while the model
    # is training.
    ds = ds.prefetch(buffer_size=AUTOTUNE)

    return ds

# %%
## prepare the dataset for training
train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

image_batch, label_batch = next(iter(val_ds))

# %%
## show sample batch of images
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(25):
        ax = plt.subplot(5,5,n+1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")

# %%
show_batch(image_batch.numpy(), label_batch.numpy())

# %% [markdown]
# # Model Building

# %%
# Init the VGG model
vgg_conv = vgg16.VGG16(weights='imagenet', include_top=False, input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[0], 3))

# Freeze all the layers
for layer in vgg_conv.layers:#[:10]:#[:-4]:
    layer.trainable = False

# Check the trainable status of the individual layers
'''
for layer in vgg_conv.layers:
    print(layer, layer.trainable)
'''
'''
for layer in vgg_conv.layers[10:]:#[:-4]:
    print(layer, len(layer.get_weights()))
    
    if len(layer.get_weights()) > 0:
        #print(layer.get_weights()[1].shape)
        layer.set_weights([
            np.random.normal(loc=0.0, scale=0.01, size=layer.get_weights()[0].shape),
            np.zeros(shape=layer.get_weights()[1].shape),
            ])

for layer in vgg_conv.layers:
    print(layer, layer.trainable)
'''
# Create the model
model = Sequential()
# Add the vgg convolutional base model
model.add(vgg_conv)
# Add new layers
model.add(Flatten())
model.add(Dense(1024, activation='relu'))
model.add(tf.keras.layers.BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))
# Show a summary of the model. Check the number of trainable parameters
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 5, 5, 512)         14714688
# _________________________________________________________________
# flatten (Flatten)            (None, 12800)             0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              13108224
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1024)              4096
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 27,828,033
# Trainable params: 13,111,297
# Non-trainable params: 14,716,736
# _________________________________________________________________

# %%
## Get the binary class ratios for correcting the imbalance
initial_bias = np.log([COUNT_PNEUMONIA/COUNT_NORMAL])
initial_bias
# Out:
# array([1.06230206])

# %%
## weigh each class according to the imbalance
## The idea is to multiply the loss with the weight, so the model focus more on the class that has a
## larger weight than a class with a smaller weight
## for loss weighting and focal loss, please refer to
## Ref: https://towardsdatascience.com/handling-imbalanced-datasets-in-deep-learning-f48407a0e758
weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0 
weight_for_1 = (1 / COUNT_PNEUMONIA)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
# Out:
# Weight for class 0: 1.95
# Weight for class 1: 0.67

# %%
#model = build_model()
## use accuracy, precision and recall to monitor the model train val performances
METRICS = [
    'accuracy',
    tf.keras.metrics.Precision(name='precision'),
    tf.keras.metrics.Recall(name='recall')
]

## since this is a binary classification problem, we can use the binary cross entropy loss function
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=METRICS
)

# %%
# ## Train the model
# history = model.fit(
#     train_ds,
#     steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
#     epochs=EPOCHS,
#     validation_data=val_ds,
#     validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
#     class_weight=class_weight,
# )

# %%
## save the best model using checkpoint callback
checkpoint_cb = tf.keras.callbacks.ModelCheckpoint("xray_model.h5",
                                                    save_best_only=True)
## To prevent the model from becoming worst (e.g. overfitting) stop the training before the issues start using the Early stopping callback
early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=10,
                                                     restore_best_weights=True)

# %%
## Decay the learning rate throught the training so the updates will gradually take smaller steps than at the begining.
def exponential_decay(lr0, s):
    def exponential_decay_fn(epoch):
        ## scale the initial learning rate by an exponential function 0.1^(e/s)
        return lr0 * 0.1 **(epoch / s)
    return exponential_decay_fn

exponential_decay_fn = exponential_decay(0.0001, 20)

lr_scheduler = tf.keras.callbacks.LearningRateScheduler(exponential_decay_fn)

# %%
history = model.fit(
    train_ds,
    steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
    epochs=100,
    validation_data=val_ds,
    validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
    class_weight=class_weight,
    callbacks=[checkpoint_cb, early_stopping_cb, lr_scheduler]
)
# Out:
# Epoch 1/100
# 32/32 [==============================] - 16s 501ms/step - loss: 0.2185 - accuracy: 0.8994 - precision: 0.9900 - recall: 0.8739 - val_loss: 0.1987 - val_accuracy: 0.9473 - val_precision: 0.9396 - val_recall: 0.9920
# Epoch 2/100
# 32/32 [==============================] - 9s 287ms/step - loss: 0.0944 - accuracy: 0.9570 - precision: 0.9969 - recall: 0.9449 - val_loss: 0.1769 - val_accuracy: 0.9756 - val_precision: 0.9753 - val_recall: 0.9921
# Epoch 3/100
# 32/32 [==============================] - 7s 227ms/step - loss: 0.0691 - accuracy: 0.9714 - precision: 0.9983 - recall: 0.9633 - val_loss: 0.1987 - val_accuracy: 0.9658 - val_precision: 0.9918 - val_recall: 0.9616
# Epoch 4/100
# 32/32 [==============================] - 9s 289ms/step - loss: 0.0556 - accuracy: 0.9792 - precision: 0.9980 - recall: 0.9740 - val_loss: 0.1297 - val_accuracy: 0.9775 - val_precision: 0.9855 - val_recall: 0.9842
# Epoch 5/100
# 32/32 [==============================] - 9s 288ms/step - loss: 0.0434 - accuracy: 0.9832 - precision: 0.9987 - recall: 0.9788 - val_loss: 0.1039 - val_accuracy: 0.9844 - val_precision: 0.9881 - val_recall: 0.9907
# Epoch 6/100
# 32/32 [==============================] - 9s 287ms/step - loss: 0.0328 - accuracy: 0.9885 - precision: 0.9983 - recall: 0.9861 - val_loss: 0.0960 - val_accuracy: 0.9785 - val_precision: 0.9855 - val_recall: 0.9855
# Epoch 7/100
# 32/32 [==============================] - 7s 227ms/step - loss: 0.0297 - accuracy: 0.9902 - precision: 1.0000 - recall: 0.9869 - val_loss: 0.1187 - val_accuracy: 0.9746 - val_precision: 0.9959 - val_recall: 0.9696
# Epoch 8/100
# 32/32 [==============================] - 9s 288ms/step - loss: 0.0249 - accuracy: 0.9937 - precision: 1.0000 - recall: 0.9915 - val_loss: 0.0847 - val_accuracy: 0.9766 - val_precision: 0.9932 - val_recall: 0.9748
# Epoch 9/100
# 32/32 [==============================] - 9s 286ms/step - loss: 0.0216 - accuracy: 0.9944 - precision: 0.9997 - recall: 0.9928 - val_loss: 0.0721 - val_accuracy: 0.9814 - val_precision: 0.9920 - val_recall: 0.9829
# Epoch 10/100
# 32/32 [==============================] - 7s 228ms/step - loss: 0.0230 - accuracy: 0.9927 - precision: 0.9993 - recall: 0.9909 - val_loss: 0.0736 - val_accuracy: 0.9775 - val_precision: 0.9946 - val_recall: 0.9749
# Epoch 11/100
# 32/32 [==============================] - 9s 291ms/step - loss: 0.0171 - accuracy: 0.9966 - precision: 0.9997 - recall: 0.9957 - val_loss: 0.0669 - val_accuracy: 0.9805 - val_precision: 0.9946 - val_recall: 0.9788
# Epoch 12/100
# 32/32 [==============================] - 7s 230ms/step - loss: 0.0151 - accuracy: 0.9956 - precision: 1.0000 - recall: 0.9941 - val_loss: 0.0760 - val_accuracy: 0.9746 - val_precision: 0.9946 - val_recall: 0.9708
# Epoch 13/100
# 32/32 [==============================] - 7s 227ms/step - loss: 0.0156 - accuracy: 0.9958 - precision: 0.9997 - recall: 0.9947 - val_loss: 0.0926 - val_accuracy: 0.9697 - val_precision: 0.9959 - val_recall: 0.9629
# Epoch 14/100
# 32/32 [==============================] - 10s 299ms/step - loss: 0.0129 - accuracy: 0.9983 - precision: 1.0000 - recall: 0.9977 - val_loss: 0.0634 - val_accuracy: 0.9795 - val_precision: 0.9933 - val_recall: 0.9788
# Epoch 15/100
# 32/32 [==============================] - 7s 224ms/step - loss: 0.0114 - accuracy: 0.9990 - precision: 1.0000 - recall: 0.9987 - val_loss: 0.0746 - val_accuracy: 0.9756 - val_precision: 0.9959 - val_recall: 0.9708
# Epoch 16/100
# 32/32 [==============================] - 7s 227ms/step - loss: 0.0123 - accuracy: 0.9980 - precision: 1.0000 - recall: 0.9974 - val_loss: 0.0699 - val_accuracy: 0.9756 - val_precision: 0.9959 - val_recall: 0.9709
# Epoch 17/100
# 32/32 [==============================] - 9s 287ms/step - loss: 0.0124 - accuracy: 0.9976 - precision: 0.9997 - recall: 0.9970 - val_loss: 0.0613 - val_accuracy: 0.9785 - val_precision: 0.9946 - val_recall: 0.9763
# Epoch 18/100
# 32/32 [==============================] - 7s 228ms/step - loss: 0.0144 - accuracy: 0.9963 - precision: 0.9993 - recall: 0.9958 - val_loss: 0.0636 - val_accuracy: 0.9785 - val_precision: 0.9959 - val_recall: 0.9749
# Epoch 19/100
# 32/32 [==============================] - 7s 229ms/step - loss: 0.0090 - accuracy: 0.9983 - precision: 1.0000 - recall: 0.9977 - val_loss: 0.0647 - val_accuracy: 0.9766 - val_precision: 0.9946 - val_recall: 0.9736
# Epoch 20/100
# 32/32 [==============================] - 7s 229ms/step - loss: 0.0112 - accuracy: 0.9978 - precision: 0.9997 - recall: 0.9974 - val_loss: 0.0615 - val_accuracy: 0.9785 - val_precision: 0.9946 - val_recall: 0.9762
# Epoch 21/100
# 32/32 [==============================] - 7s 228ms/step - loss: 0.0086 - accuracy: 0.9983 - precision: 1.0000 - recall: 0.9977 - val_loss: 0.0637 - val_accuracy: 0.9766 - val_precision: 0.9946 - val_recall: 0.9735
# Epoch 22/100
# 32/32 [==============================] - 9s 293ms/step - loss: 0.0080 - accuracy: 0.9993 - precision: 1.0000 - recall: 0.9990 - val_loss: 0.0585 - val_accuracy: 0.9814 - val_precision: 0.9946 - val_recall: 0.9801
# Epoch 23/100
# 32/32 [==============================] - 9s 287ms/step - loss: 0.0081 - accuracy: 0.9990 - precision: 1.0000 - recall: 0.9987 - val_loss: 0.0584 - val_accuracy: 0.9824 - val_precision: 0.9946 - val_recall: 0.9815
# Epoch 24/100
# 32/32 [==============================] - 7s 228ms/step - loss: 0.0081 - accuracy: 0.9993 - precision: 1.0000 - recall: 0.9990 - val_loss: 0.0621 - val_accuracy: 0.9795 - val_precision: 0.9946 - val_recall: 0.9776
# Epoch 25/100
# 32/32 [==============================] - 9s 291ms/step - loss: 0.0086 - accuracy: 0.9993 - precision: 1.0000 - recall: 0.9990 - val_loss: 0.0576 - val_accuracy: 0.9824 - val_precision: 0.9946 - val_recall: 0.9815
# Epoch 26/100
# 32/32 [==============================] - 7s 228ms/step - loss: 0.0093 - accuracy: 0.9993 - precision: 1.0000 - recall: 0.9990 - val_loss: 0.0622 - val_accuracy: 0.9785 - val_precision: 0.9946 - val_recall: 0.9762
# Epoch 27/100
# 32/32 [==============================] - 7s 227ms/step - loss: 0.0081 - accuracy: 0.9985 - precision: 1.0000 - recall: 0.9980 - val_loss: 0.0594 - val_accuracy: 0.9814 - val_precision: 0.9946 - val_recall: 0.9802
# Epoch 28/100
# 32/32 [==============================] - 7s 227ms/step - loss: 0.0082 - accuracy: 0.9995 - precision: 1.0000 - recall: 0.9993 - val_loss: 0.0647 - val_accuracy: 0.9785 - val_precision: 0.9946 - val_recall: 0.9763
# Epoch 29/100
# 32/32 [==============================] - 7s 230ms/step - loss: 0.0081 - accuracy: 0.9995 - precision: 1.0000 - recall: 0.9993 - val_loss: 0.0588 - val_accuracy: 0.9805 - val_precision: 0.9960 - val_recall: 0.9775
# Epoch 30/100
# 32/32 [==============================] - 7s 226ms/step - loss: 0.0085 - accuracy: 0.9983 - precision: 1.0000 - recall: 0.9977 - val_loss: 0.0601 - val_accuracy: 0.9824 - val_precision: 0.9946 - val_recall: 0.9815
# Epoch 31/100
# 32/32 [==============================] - 11s 329ms/step - loss: 0.0077 - accuracy: 0.9988 - precision: 1.0000 - recall: 0.9984 - val_loss: 0.0568 - val_accuracy: 0.9824 - val_precision: 0.9960 - val_recall: 0.9802
# Epoch 32/100
# 32/32 [==============================] - 7s 226ms/step - loss: 0.0087 - accuracy: 0.9990 - precision: 1.0000 - recall: 0.9987 - val_loss: 0.0608 - val_accuracy: 0.9814 - val_precision: 0.9946 - val_recall: 0.9801
# Epoch 33/100
# 32/32 [==============================] - 7s 226ms/step - loss: 0.0077 - accuracy: 0.9995 - precision: 1.0000 - recall: 0.9993 - val_loss: 0.0619 - val_accuracy: 0.9814 - val_precision: 0.9947 - val_recall: 0.9802
# Epoch 34/100
# 32/32 [==============================] - 7s 228ms/step - loss: 0.0086 - accuracy: 0.9993 - precision: 1.0000 - recall: 0.9990 - val_loss: 0.0636 - val_accuracy: 0.9785 - val_precision: 0.9946 - val_recall: 0.9762
# Epoch 35/100
# 32/32 [==============================] - 7s 228ms/step - loss: 0.0075 - accuracy: 0.9993 - precision: 1.0000 - recall: 0.9990 - val_loss: 0.0641 - val_accuracy: 0.9785 - val_precision: 0.9946 - val_recall: 0.9761
# Epoch 36/100
# 32/32 [==============================] - 7s 230ms/step - loss: 0.0076 - accuracy: 0.9990 - precision: 1.0000 - recall: 0.9987 - val_loss: 0.0617 - val_accuracy: 0.9795 - val_precision: 0.9960 - val_recall: 0.9763
# Epoch 37/100
# 32/32 [==============================] - 7s 231ms/step - loss: 0.0070 - accuracy: 0.9983 - precision: 1.0000 - recall: 0.9977 - val_loss: 0.0641 - val_accuracy: 0.9785 - val_precision: 0.9946 - val_recall: 0.9763
# Epoch 38/100
# 32/32 [==============================] - 7s 229ms/step - loss: 0.0077 - accuracy: 0.9988 - precision: 1.0000 - recall: 0.9983 - val_loss: 0.0635 - val_accuracy: 0.9785 - val_precision: 0.9946 - val_recall: 0.9762
# Epoch 39/100
# 32/32 [==============================] - 7s 229ms/step - loss: 0.0063 - accuracy: 0.9993 - precision: 1.0000 - recall: 0.9990 - val_loss: 0.0626 - val_accuracy: 0.9795 - val_precision: 0.9946 - val_recall: 0.9775
# Epoch 40/100
# 32/32 [==============================] - 7s 230ms/step - loss: 0.0073 - accuracy: 0.9985 - precision: 1.0000 - recall: 0.9980 - val_loss: 0.0617 - val_accuracy: 0.9805 - val_precision: 0.9946 - val_recall: 0.9788
# Epoch 41/100
# 32/32 [==============================] - 11s 329ms/step - loss: 0.0090 - accuracy: 0.9988 - precision: 1.0000 - recall: 0.9984 - val_loss: 0.0546 - val_accuracy: 0.9814 - val_precision: 0.9946 - val_recall: 0.9802
# Epoch 42/100
# 32/32 [==============================] - 7s 227ms/step - loss: 0.0067 - accuracy: 0.9993 - precision: 1.0000 - recall: 0.9990 - val_loss: 0.0615 - val_accuracy: 0.9805 - val_precision: 0.9946 - val_recall: 0.9788
# Epoch 43/100
# 32/32 [==============================] - 7s 230ms/step - loss: 0.0073 - accuracy: 0.9995 - precision: 1.0000 - recall: 0.9993 - val_loss: 0.0630 - val_accuracy: 0.9805 - val_precision: 0.9946 - val_recall: 0.9788
# Epoch 44/100
# 32/32 [==============================] - 7s 229ms/step - loss: 0.0066 - accuracy: 0.9990 - precision: 1.0000 - recall: 0.9987 - val_loss: 0.0599 - val_accuracy: 0.9814 - val_precision: 0.9946 - val_recall: 0.9801
# Epoch 45/100
# 32/32 [==============================] - 7s 230ms/step - loss: 0.0084 - accuracy: 0.9976 - precision: 1.0000 - recall: 0.9967 - val_loss: 0.0618 - val_accuracy: 0.9814 - val_precision: 0.9946 - val_recall: 0.9802
# Epoch 46/100
# 32/32 [==============================] - 7s 227ms/step - loss: 0.0085 - accuracy: 0.9983 - precision: 1.0000 - recall: 0.9977 - val_loss: 0.0621 - val_accuracy: 0.9814 - val_precision: 0.9946 - val_recall: 0.9801
# Epoch 47/100
# 32/32 [==============================] - 7s 228ms/step - loss: 0.0085 - accuracy: 0.9983 - precision: 1.0000 - recall: 0.9977 - val_loss: 0.0618 - val_accuracy: 0.9814 - val_precision: 0.9946 - val_recall: 0.9802
# Epoch 48/100
# 32/32 [==============================] - 7s 230ms/step - loss: 0.0067 - accuracy: 0.9988 - precision: 1.0000 - recall: 0.9984 - val_loss: 0.0594 - val_accuracy: 0.9824 - val_precision: 0.9946 - val_recall: 0.9815
# Epoch 49/100
# 32/32 [==============================] - 7s 227ms/step - loss: 0.0070 - accuracy: 0.9993 - precision: 1.0000 - recall: 0.9990 - val_loss: 0.0618 - val_accuracy: 0.9814 - val_precision: 0.9946 - val_recall: 0.9802
# Epoch 50/100
# 32/32 [==============================] - 7s 228ms/step - loss: 0.0069 - accuracy: 0.9998 - precision: 1.0000 - recall: 0.9997 - val_loss: 0.0592 - val_accuracy: 0.9814 - val_precision: 0.9946 - val_recall: 0.9802
# Epoch 51/100
# 32/32 [==============================] - 7s 230ms/step - loss: 0.0078 - accuracy: 0.9985 - precision: 1.0000 - recall: 0.9980 - val_loss: 0.0622 - val_accuracy: 0.9814 - val_precision: 0.9946 - val_recall: 0.9801

# %%
## visualize the performance
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
fig.savefig('./plots/binary_vgg_all_frozen.png')
