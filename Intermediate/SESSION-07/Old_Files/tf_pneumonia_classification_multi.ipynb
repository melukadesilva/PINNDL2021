# %%
#!pip install pandas
#!pip install tensorflow-gpu
#!pip install matplotlib
#!pip install sklearn

# %%
import re
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
## Ref: https://www.tensorflow.org/guide/data_performance
AUTOTUNE = tf.data.experimental.AUTOTUNE ## Auto tune tf.data hyper parameters for 
## data loading performance
FILE_PATH = '/media/akaaku13m/af04068d-3c77-49e2-977e-15b2e7dd348e/research_assistance_work/courses/PINNDL/local/data'
#GCS_PATH = KaggleDatasets().get_gcs_path()
BATCH_SIZE = 16 * 8#strategy.num_replicas_in_sync
IMAGE_SIZE = [180, 180]
EPOCHS = 25

# %% [markdown]
# # Data Preperation

# %%
filenames = tf.io.gfile.glob(str(FILE_PATH + '/chest_xray/train/*/*'))
filenames.extend(tf.io.gfile.glob(str(FILE_PATH + '/chest_xray/val/*/*')))

## since there are 16 images for the validation set, first both train and test sets are
## combined and then the dataset is split with 80, 20 rule (80% training, 20% testing)
train_filenames, val_filenames = train_test_split(filenames, test_size=0.2)

# %%
# COUNT_NORMAL = len([filename for filename in train_filenames if "NORMAL" in filename])
# print("Normal images count in training set: " + str(COUNT_NORMAL))

# COUNT_PNEUMONIA = len([filename for filename in train_filenames if "PNEUMONIA" in filename])
# print("Pneumonia images count in training set: " + str(COUNT_PNEUMONIA))
COUNT_NORMAL = 0
COUNT_BACTERIA = 0
COUNT_VIRUS = 0

for f in train_filenames:
    name = f.split('/')
    if name[-2] == "NORMAL":
        COUNT_NORMAL += 1
    else:
        label = name[-1].split('_')[-2]
        if label == "bacteria":
            COUNT_BACTERIA += 1
        else:
            COUNT_VIRUS += 1

print(COUNT_NORMAL)
print(COUNT_BACTERIA)
print(COUNT_VIRUS)
# Out:
# 1070
# 2029
# 1086

# %%
## put the file names in a tf tensor
train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

## view few of the file names
for f in train_list_ds.take(5):
    print(f.numpy())
# Out:
# b'/media/akaaku13m/af04068d-3c77-49e2-977e-15b2e7dd348e/research_assistance_work/courses/PINNDL/local/data/chest_xray/train/PNEUMONIA/person440_bacteria_1897.jpeg'
# b'/media/akaaku13m/af04068d-3c77-49e2-977e-15b2e7dd348e/research_assistance_work/courses/PINNDL/local/data/chest_xray/train/PNEUMONIA/person265_bacteria_1235.jpeg'
# b'/media/akaaku13m/af04068d-3c77-49e2-977e-15b2e7dd348e/research_assistance_work/courses/PINNDL/local/data/chest_xray/train/PNEUMONIA/person1216_bacteria_3168.jpeg'
# b'/media/akaaku13m/af04068d-3c77-49e2-977e-15b2e7dd348e/research_assistance_work/courses/PINNDL/local/data/chest_xray/train/PNEUMONIA/person1220_bacteria_3173.jpeg'
# b'/media/akaaku13m/af04068d-3c77-49e2-977e-15b2e7dd348e/research_assistance_work/courses/PINNDL/local/data/chest_xray/train/PNEUMONIA/person351_bacteria_1619.jpeg'

# %%
## cardinality gives the number of unique elements in the dataset
## Ref: https://orangematter.solarwinds.com/2020/01/05/what-is-cardinality-in-a-database/
## Ref: https://www.tensorflow.org/api_docs/python/tf/data/experimental/cardinality
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print("Training images count: " + str(TRAIN_IMG_COUNT))

VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print("Validating images count: " + str(VAL_IMG_COUNT))
# Out:
# Training images count: 4185
# Validating images count: 1047

# %%
## View the two classes
CLASS_NAMES = np.array([str(tf.strings.split(item, os.path.sep)[-1].numpy())[2:-1]
                        for item in tf.io.gfile.glob(str(FILE_PATH + "/chest_xray/train/*"))])
CLASS_NAMES
# Out:
# array(['PNEUMONIA', 'NORMAL'], dtype='<U9')

# %%
## Returns 0 or 1 (False or True) labels
## 1 indicates the Pneumonia class and 0 indicates a Normal class
## label map
keys_tensor = tf.constant(['normal', 'bacteria', 'virus'])
vals_tensor = tf.constant([0, 1, 2])
init = tf.lookup.KeyValueTensorInitializer(keys_tensor, vals_tensor)
table = tf.lookup.StaticHashTable(
    init,
    default_value=-1)
def get_label(file_path):
    # convert the path to a list of path components
    parts = tf.strings.split(file_path, os.path.sep)
    ## check if pneumonia type or normal 
    if parts[-2] == "NORMAL":
        label = tf.constant('normal')
    else:
        label = tf.strings.split(parts[-1], '_')[-2]
    lbl_idx = table.lookup(label)
    return tf.one_hot(lbl_idx, 3)
    # The second to last is the class-directory
    #return parts[-2] == "PNEUMONIA"

# %%
def decode_img(img):
  # convert the compressed string to a 3D uint8 tensor
  img = tf.image.decode_jpeg(img, channels=3)
  # Use `convert_image_dtype` to convert to floats in the [0,1] range.
  img = tf.image.convert_image_dtype(img, tf.float32)
  # resize the image to the desired size.
  return tf.image.resize(img, IMAGE_SIZE)

# %%
## from a given file path get the label and the corresponding image
def process_path(file_path):
    #print(file_path)
    label = get_label(file_path)
    # load the raw data from the file as a string
    img = tf.io.read_file(file_path)
    img = decode_img(img)
    return img, label

# %%
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
print(AUTOTUNE)
# Out:
# -1

# %%
## check the new dataset
for image, label in train_ds.take(10):
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
    #print("File path", fpath.numpy())
# Out:
# Image shape:  (180, 180, 3)
# Label:  [0. 1. 0.]
# Image shape:  (180, 180, 3)
# Label:  [0. 1. 0.]
# Image shape:  (180, 180, 3)
# Label:  [0. 1. 0.]
# Image shape:  (180, 180, 3)
# Label:  [0. 1. 0.]
# Image shape:  (180, 180, 3)
# Label:  [0. 1. 0.]
# Image shape:  (180, 180, 3)
# Label:  [0. 1. 0.]
# Image shape:  (180, 180, 3)
# Label:  [1. 0. 0.]
# Image shape:  (180, 180, 3)
# Label:  [0. 0. 1.]
# Image shape:  (180, 180, 3)
# Label:  [1. 0. 0.]
# Image shape:  (180, 180, 3)
# Label:  [0. 1. 0.]

# %%
## Prepare a test dataset for validating the model performances after training
test_list_ds = tf.data.Dataset.list_files(str(FILE_PATH + '/chest_xray/test/*/*'))
TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

TEST_IMAGE_COUNT
# Out:
# 624

# %%
## For caching, repeat, and prefetch, please refer to
## Ref: https://www.tensorflow.org/api_docs/python/tf/data/Dataset
def prepare_for_training(ds, cache=True, shuffle_buffer_size=1000):
    # This is a small dataset, only load it once, and keep it in memory.
    # use `.cache(filename)` to cache preprocessing work for datasets that don't
    # fit in memory.
    if cache:
        if isinstance(cache, str): ## if caching to a file
            ds = ds.cache(cache)
        else: ## cache in memory
            ds = ds.cache()
    ## shuffle data, otherwise, data will be cached with the same patten (not random)
    ds = ds.shuffle(buffer_size=shuffle_buffer_size)

    # Repeat forever
    ds = ds.repeat()

    ds = ds.batch(BATCH_SIZE)

    # `prefetch` lets the dataset fetch batches in the background while the model
    # is training.
    ds = ds.prefetch(buffer_size=AUTOTUNE)

    return ds

# %%
## prepare the dataset for training
train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

image_batch, label_batch = next(iter(train_ds))

# %%
## show sample batch of images
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(25):
        ax = plt.subplot(5,5,n+1)
        plt.imshow(image_batch[n])
        if tf.math.argmax(label_batch[n]).numpy() == 1:
            plt.title("BACTERIA")
        elif tf.math.argmax(label_batch[n]).numpy() == 2:
            plt.title("VIRUS")
        else:
            plt.title("NORMAL")
        plt.axis("off")

# %%
show_batch(image_batch.numpy(), label_batch.numpy())

# %% [markdown]
# # Model Building

# %%
def conv_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ])
    
    return block

# %%
def dense_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate)
    ])
    
    return block

# %%
def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        
        conv_block(32),
        conv_block(64),
        
        conv_block(128),
        tf.keras.layers.Dropout(0.2),
        
        conv_block(256),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),
        
        tf.keras.layers.Dense(3, activation='softmax')
    ])
    
    return model

# %%
## weigh each class according to the imbalance
## The idea is to multiply the loss with the weight, so the model focus more on the class that has a
## larger weight than a class with a smaller weight
## for loss weighting and focal loss, please refer to
## Ref: https://towardsdatascience.com/handling-imbalanced-datasets-in-deep-learning-f48407a0e758
weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0 
weight_for_1 = (1 / COUNT_BACTERIA)*(TRAIN_IMG_COUNT)/2.0
weight_for_2 = (1 / COUNT_VIRUS)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1, 2: weight_for_2}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
print('Weight for class 2: {:.2f}'.format(weight_for_2))
# Out:
# Weight for class 0: 1.96
# Weight for class 1: 1.03
# Weight for class 2: 1.93

# %%
model = build_model()
## use accuracy, precision and recall to monitor the model train val performances
METRICS = [
    'accuracy',
    tf.keras.metrics.Precision(name='precision'),
    tf.keras.metrics.Recall(name='recall')
]

## since this is a binary classification problem, we can use the binary cross entropy loss function
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=METRICS
)

# %%
# ## Train the model
# history = model.fit(
#     train_ds,
#     steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
#     epochs=EPOCHS,
#     validation_data=val_ds,
#     validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
#     class_weight=class_weight,
# )

# %%
## save the best model using checkpoint callback
checkpoint_cb = tf.keras.callbacks.ModelCheckpoint("xray_model.h5",
                                                    save_best_only=True)
## To prevent the model from becoming worst (e.g. overfitting) stop the training before the issues start using the Early stopping callback
early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=10,
                                                     restore_best_weights=True)

# %%
## Decay the learning rate throught the training so the updates will gradually take smaller steps than at the begining.
def exponential_decay(lr0, s):
    def exponential_decay_fn(epoch):
        ## scale the initial learning rate by an exponential function 0.1^(e/s)
        return lr0 * 0.1 **(epoch / s)
    return exponential_decay_fn

exponential_decay_fn = exponential_decay(0.01, 20)

lr_scheduler = tf.keras.callbacks.LearningRateScheduler(exponential_decay_fn)

# %%
history = model.fit(
    train_ds,
    steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
    epochs=100,
    validation_data=val_ds,
    validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
    class_weight=class_weight,
    callbacks=[checkpoint_cb, lr_scheduler]
)
# Out:
# .8168 - recall: 0.8022 - val_loss: 0.8821 - val_accuracy: 0.6533 - val_precision: 0.6791 - val_recall: 0.6201
# Epoch 13/100
# 32/32 [==============================] - 9s 281ms/step - loss: 0.5858 - accuracy: 0.8081 - precision: 0.8154 - recall: 0.8002 - val_loss: 1.3010 - val_accuracy: 0.5566 - val_precision: 0.5802 - val_recall: 0.5439
# Epoch 14/100
# 32/32 [==============================] - 9s 285ms/step - loss: 0.5562 - accuracy: 0.8213 - precision: 0.8277 - recall: 0.8127 - val_loss: 1.0286 - val_accuracy: 0.5928 - val_precision: 0.6000 - val_recall: 0.5742
# Epoch 15/100
# 32/32 [==============================] - 10s 307ms/step - loss: 0.5618 - accuracy: 0.8079 - precision: 0.8131 - recall: 0.8029 - val_loss: 0.5904 - val_accuracy: 0.7539 - val_precision: 0.7635 - val_recall: 0.7441
# Epoch 16/100
# 32/32 [==============================] - 9s 286ms/step - loss: 0.5176 - accuracy: 0.8318 - precision: 0.8356 - recall: 0.8269 - val_loss: 0.6091 - val_accuracy: 0.7451 - val_precision: 0.7547 - val_recall: 0.7393
# Epoch 17/100
# 32/32 [==============================] - 9s 286ms/step - loss: 0.5296 - accuracy: 0.8267 - precision: 0.8307 - recall: 0.8217 - val_loss: 0.7113 - val_accuracy: 0.7158 - val_precision: 0.7298 - val_recall: 0.7070
# Epoch 18/100
# 32/32 [==============================] - 9s 294ms/step - loss: 0.5115 - accuracy: 0.8301 - precision: 0.8336 - recall: 0.8259 - val_loss: 0.5547 - val_accuracy: 0.7705 - val_precision: 0.7744 - val_recall: 0.7607
# Epoch 19/100
# 32/32 [==============================] - 9s 290ms/step - loss: 0.4671 - accuracy: 0.8447 - precision: 0.8471 - recall: 0.8403 - val_loss: 0.4729 - val_accuracy: 0.8047 - val_precision: 0.8081 - val_recall: 0.7979
# Epoch 20/100
# 32/32 [==============================] - 9s 281ms/step - loss: 0.4670 - accuracy: 0.8459 - precision: 0.8513 - recall: 0.8430 - val_loss: 0.5982 - val_accuracy: 0.7598 - val_precision: 0.7732 - val_recall: 0.7559
# Epoch 21/100
# 32/32 [==============================] - 9s 281ms/step - loss: 0.4759 - accuracy: 0.8425 - precision: 0.8452 - recall: 0.8386 - val_loss: 0.5629 - val_accuracy: 0.7598 - val_precision: 0.7648 - val_recall: 0.7559
# Epoch 22/100
# 32/32 [==============================] - 9s 279ms/step - loss: 0.4500 - accuracy: 0.8464 - precision: 0.8490 - recall: 0.8442 - val_loss: 0.5142 - val_accuracy: 0.7939 - val_precision: 0.7970 - val_recall: 0.7900
# Epoch 23/100
# 32/32 [==============================] - 9s 283ms/step - loss: 0.4280 - accuracy: 0.8586 - precision: 0.8618 - recall: 0.8544 - val_loss: 0.5290 - val_accuracy: 0.7881 - val_precision: 0.7937 - val_recall: 0.7852
# Epoch 24/100
# 32/32 [==============================] - 9s 279ms/step - loss: 0.4020 - accuracy: 0.8672 - precision: 0.8690 - recall: 0.8647 - val_loss: 0.4850 - val_accuracy: 0.8154 - val_precision: 0.8183 - val_recall: 0.8135
# Epoch 25/100
# 32/32 [==============================] - 9s 278ms/step - loss: 0.3977 - accuracy: 0.8738 - precision: 0.8754 - recall: 0.8718 - val_loss: 0.4776 - val_accuracy: 0.8164 - val_precision: 0.8189 - val_recall: 0.8125
# Epoch 26/100
# 32/32 [==============================] - 9s 277ms/step - loss: 0.3794 - accuracy: 0.8787 - precision: 0.8808 - recall: 0.8767 - val_loss: 0.4975 - val_accuracy: 0.8096 - val_precision: 0.8106 - val_recall: 0.8066
# Epoch 27/100
# 32/32 [==============================] - 9s 280ms/step - loss: 0.3923 - accuracy: 0.8772 - precision: 0.8783 - recall: 0.8757 - val_loss: 0.5532 - val_accuracy: 0.7959 - val_precision: 0.7992 - val_recall: 0.7930
# Epoch 28/100
# 32/32 [==============================] - 9s 276ms/step - loss: 0.3617 - accuracy: 0.8845 - precision: 0.8878 - recall: 0.8830 - val_loss: 0.4986 - val_accuracy: 0.8125 - val_precision: 0.8137 - val_recall: 0.8105
# Epoch 29/100
# 32/32 [==============================] - 9s 279ms/step - loss: 0.3534 - accuracy: 0.8884 - precision: 0.8898 - recall: 0.8872 - val_loss: 0.5318 - val_accuracy: 0.8047 - val_precision: 0.8107 - val_recall: 0.8027
# Epoch 30/100
# 32/32 [==============================] - 9s 281ms/step - loss: 0.3455 - accuracy: 0.8914 - precision: 0.8929 - recall: 0.8894 - val_loss: 0.5340 - val_accuracy: 0.8096 - val_precision: 0.8110 - val_recall: 0.8047
# Epoch 31/100
# 32/32 [==============================] - 9s 277ms/step - loss: 0.3463 - accuracy: 0.8887 - precision: 0.8889 - recall: 0.8874 - val_loss: 0.5156 - val_accuracy: 0.8086 - val_precision: 0.8116 - val_recall: 0.8076
# Epoch 32/100
# 32/32 [==============================] - 9s 279ms/step - loss: 0.3396 - accuracy: 0.8953 - precision: 0.8980 - recall: 0.8940 - val_loss: 0.5384 - val_accuracy: 0.8174 - val_precision: 0.8180 - val_recall: 0.8164
# Epoch 33/100
# 32/32 [==============================] - 9s 274ms/step - loss: 0.3179 - accuracy: 0.9021 - precision: 0.9029 - recall: 0.9011 - val_loss: 0.5424 - val_accuracy: 0.8115 - val_precision: 0.8137 - val_recall: 0.8105
# Epoch 34/100
# 32/32 [==============================] - 9s 281ms/step - loss: 0.3311 - accuracy: 0.8918 - precision: 0.8934 - recall: 0.8899 - val_loss: 0.5276 - val_accuracy: 0.8086 - val_precision: 0.8114 - val_recall: 0.8066
# Epoch 35/100
# 32/32 [==============================] - 9s 273ms/step - loss: 0.3225 - accuracy: 0.9006 - precision: 0.9021 - recall: 0.9003 - val_loss: 0.5270 - val_accuracy: 0.8184 - val_precision: 0.8202 - val_recall: 0.8154
# Epoch 36/100
# 32/32 [==============================] - 9s 278ms/step - loss: 0.3171 - accuracy: 0.9023 - precision: 0.9033 - recall: 0.9011 - val_loss: 0.5405 - val_accuracy: 0.8164 - val_precision: 0.8167 - val_recall: 0.8135
# Epoch 37/100
# 32/32 [==============================] - 9s 275ms/step - loss: 0.3082 - accuracy: 0.9062 - precision: 0.9079 - recall: 0.9055 - val_loss: 0.5340 - val_accuracy: 0.8086 - val_precision: 0.8126 - val_recall: 0.8047
# Epoch 38/100
# 32/32 [==============================] - 9s 280ms/step - loss: 0.3115 - accuracy: 0.9028 - precision: 0.9032 - recall: 0.9016 - val_loss: 0.5361 - val_accuracy: 0.8037 - val_precision: 0.8041 - val_recall: 0.8018
# Epoch 39/100
# 32/32 [==============================] - 9s 278ms/step - loss: 0.2975 - accuracy: 0.9036 - precision: 0.9046 - recall: 0.9028 - val_loss: 0.5382 - val_accuracy: 0.8096 - val_precision: 0.8116 - val_recall: 0.8076
# Epoch 40/100
# 32/32 [==============================] - 9s 281ms/step - loss: 0.3073 - accuracy: 0.9111 - precision: 0.9130 - recall: 0.9101 - val_loss: 0.5380 - val_accuracy: 0.8125 - val_precision: 0.8131 - val_recall: 0.8115
# Epoch 41/100
# 32/32 [==============================] - 9s 277ms/step - loss: 0.2955 - accuracy: 0.9058 - precision: 0.9063 - recall: 0.9048 - val_loss: 0.5276 - val_accuracy: 0.8037 - val_precision: 0.8061 - val_recall: 0.7998
# Epoch 42/100
# 32/32 [==============================] - 9s 276ms/step - loss: 0.3083 - accuracy: 0.9050 - precision: 0.9064 - recall: 0.9033 - val_loss: 0.5427 - val_accuracy: 0.8057 - val_precision: 0.8063 - val_recall: 0.8047
# Epoch 43/100
# 32/32 [==============================] - 9s 284ms/step - loss: 0.2886 - accuracy: 0.9128 - precision: 0.9136 - recall: 0.9116 - val_loss: 0.5350 - val_accuracy: 0.8066 - val_precision: 0.8112 - val_recall: 0.8057
# Epoch 44/100
# 32/32 [==============================] - 9s 282ms/step - loss: 0.2936 - accuracy: 0.9136 - precision: 0.9150 - recall: 0.9126 - val_loss: 0.5540 - val_accuracy: 0.8018 - val_precision: 0.8033 - val_recall: 0.8018
# Epoch 45/100
# 32/32 [==============================] - 9s 283ms/step - loss: 0.2959 - accuracy: 0.9070 - precision: 0.9079 - recall: 0.9048 - val_loss: 0.5622 - val_accuracy: 0.7998 - val_precision: 0.8020 - val_recall: 0.7988
# Epoch 46/100
# 32/32 [==============================] - 9s 280ms/step - loss: 0.3001 - accuracy: 0.9038 - precision: 0.9051 - recall: 0.9035 - val_loss: 0.5584 - val_accuracy: 0.8057 - val_precision: 0.8078 - val_recall: 0.8047
# Epoch 47/100
# 32/32 [==============================] - 9s 284ms/step - loss: 0.2777 - accuracy: 0.9126 - precision: 0.9141 - recall: 0.9116 - val_loss: 0.5580 - val_accuracy: 0.8076 - val_precision: 0.8090 - val_recall: 0.8066
# Epoch 48/100
# 32/32 [==============================] - 9s 283ms/step - loss: 0.2754 - accuracy: 0.9185 - precision: 0.9200 - recall: 0.9179 - val_loss: 0.5576 - val_accuracy: 0.8027 - val_precision: 0.8035 - val_recall: 0.8027
# Epoch 49/100
# 32/32 [==============================] - 9s 285ms/step - loss: 0.2759 - accuracy: 0.9204 - precision: 0.9213 - recall: 0.9182 - val_loss: 0.5442 - val_accuracy: 0.8086 - val_precision: 0.8090 - val_recall: 0.8066
# Epoch 50/100
# 32/32 [==============================] - 9s 281ms/step - loss: 0.2769 - accuracy: 0.9146 - precision: 0.9159 - recall: 0.9143 - val_loss: 0.5570 - val_accuracy: 0.8008 - val_precision: 0.8029 - val_recall: 0.7998
# Epoch 51/100
# 32/32 [==============================] - 9s 275ms/step - loss: 0.2804 - accuracy: 0.9189 - precision: 0.9209 - recall: 0.9177 - val_loss: 0.5627 - val_accuracy: 0.8037 - val_precision: 0.8041 - val_recall: 0.8018
# Epoch 52/100
# 32/32 [==============================] - 9s 277ms/step - loss: 0.2765 - accuracy: 0.9160 - precision: 0.9173 - recall: 0.9158 - val_loss: 0.5593 - val_accuracy: 0.8047 - val_precision: 0.8061 - val_recall: 0.8037
# Epoch 53/100
# 32/32 [==============================] - 9s 271ms/step - loss: 0.2873 - accuracy: 0.9087 - precision: 0.9107 - recall: 0.9087 - val_loss: 0.5507 - val_accuracy: 0.8096 - val_precision: 0.8126 - val_recall: 0.8086
# Epoch 54/100
# 32/32 [==============================] - 9s 282ms/step - loss: 0.2804 - accuracy: 0.9141 - precision: 0.9155 - recall: 0.9131 - val_loss: 0.5473 - val_accuracy: 0.8105 - val_precision: 0.8108 - val_recall: 0.8076
# Epoch 55/100
# 32/32 [==============================] - 9s 277ms/step - loss: 0.2666 - accuracy: 0.9170 - precision: 0.9173 - recall: 0.9160 - val_loss: 0.5547 - val_accuracy: 0.8057 - val_precision: 0.8067 - val_recall: 0.8027
# Epoch 56/100
# 32/32 [==============================] - 9s 281ms/step - loss: 0.2737 - accuracy: 0.9170 - precision: 0.9173 - recall: 0.9158 - val_loss: 0.5530 - val_accuracy: 0.8076 - val_precision: 0.8106 - val_recall: 0.8066
# Epoch 57/100
# 32/32 [==============================] - 9s 280ms/step - loss: 0.2781 - accuracy: 0.9116 - precision: 0.9131 - recall: 0.9114 - val_loss: 0.5670 - val_accuracy: 0.8027 - val_precision: 0.8027 - val_recall: 0.7988
# Epoch 58/100
# 32/32 [==============================] - 9s 281ms/step - loss: 0.2617 - accuracy: 0.9187 - precision: 0.9201 - recall: 0.9172 - val_loss: 0.5621 - val_accuracy: 0.8037 - val_precision: 0.8055 - val_recall: 0.8008
# Epoch 59/100
# 32/32 [==============================] - 9s 278ms/step - loss: 0.2747 - accuracy: 0.9131 - precision: 0.9133 - recall: 0.9128 - val_loss: 0.5581 - val_accuracy: 0.8047 - val_precision: 0.8057 - val_recall: 0.8018
# Epoch 60/100
# 32/32 [==============================] - 9s 284ms/step - loss: 0.2867 - accuracy: 0.9114 - precision: 0.9126 - recall: 0.9106 - val_loss: 0.5632 - val_accuracy: 0.8037 - val_precision: 0.8057 - val_recall: 0.8018
# Epoch 61/100
# 32/32 [==============================] - 9s 285ms/step - loss: 0.2848 - accuracy: 0.9111 - precision: 0.9135 - recall: 0.9099 - val_loss: 0.5650 - val_accuracy: 0.8018 - val_precision: 0.8037 - val_recall: 0.7998
# Epoch 62/100
# 32/32 [==============================] - 9s 284ms/step - loss: 0.2693 - accuracy: 0.9233 - precision: 0.9241 - recall: 0.9223 - val_loss: 0.5671 - val_accuracy: 0.8027 - val_precision: 0.8045 - val_recall: 0.7998
# Epoch 63/100
# 32/32 [==============================] - 9s 279ms/step - loss: 0.2759 - accuracy: 0.9148 - precision: 0.9154 - recall: 0.9148 - val_loss: 0.5456 - val_accuracy: 0.8047 - val_precision: 0.8067 - val_recall: 0.8027
# Epoch 64/100
# 32/32 [==============================] - 9s 277ms/step - loss: 0.2722 - accuracy: 0.9167 - precision: 0.9178 - recall: 0.9160 - val_loss: 0.5518 - val_accuracy: 0.8086 - val_precision: 0.8094 - val_recall: 0.8047
# Epoch 65/100
# 32/32 [==============================] - 9s 281ms/step - loss: 0.2910 - accuracy: 0.9136 - precision: 0.9152 - recall: 0.9123 - val_loss: 0.5597 - val_accuracy: 0.8066 - val_precision: 0.8069 - val_recall: 0.8037
# Epoch 66/100
# 32/32 [==============================] - 9s 276ms/step - loss: 0.2776 - accuracy: 0.9153 - precision: 0.9168 - recall: 0.9145 - val_loss: 0.5672 - val_accuracy: 0.8037 - val_precision: 0.8051 - val_recall: 0.8027
# Epoch 67/100
# 32/32 [==============================] - 9s 276ms/step - loss: 0.2687 - accuracy: 0.9177 - precision: 0.9188 - recall: 0.9172 - val_loss: 0.5583 - val_accuracy: 0.8037 - val_precision: 0.8059 - val_recall: 0.8027
# Epoch 68/100
# 32/32 [==============================] - 9s 283ms/step - loss: 0.2772 - accuracy: 0.9177 - precision: 0.9189 - recall: 0.9158 - val_loss: 0.5619 - val_accuracy: 0.8027 - val_precision: 0.8045 - val_recall: 0.7998
# Epoch 69/100
# 32/32 [==============================] - 9s 273ms/step - loss: 0.2707 - accuracy: 0.9175 - precision: 0.9183 - recall: 0.9170 - val_loss: 0.5714 - val_accuracy: 0.8008 - val_precision: 0.8026 - val_recall: 0.7979
# Epoch 70/100
# 32/32 [==============================] - 9s 277ms/step - loss: 0.2761 - accuracy: 0.9189 - precision: 0.9202 - recall: 0.9184 - val_loss: 0.5559 - val_accuracy: 0.8057 - val_precision: 0.8077 - val_recall: 0.8037
# Epoch 71/100
# 32/32 [==============================] - 9s 277ms/step - loss: 0.2834 - accuracy: 0.9126 - precision: 0.9143 - recall: 0.9118 - val_loss: 0.5608 - val_accuracy: 0.8037 - val_precision: 0.8065 - val_recall: 0.8018
# Epoch 72/100
# 32/32 [==============================] - 9s 274ms/step - loss: 0.2745 - accuracy: 0.9170 - precision: 0.9179 - recall: 0.9150 - val_loss: 0.5630 - val_accuracy: 0.8047 - val_precision: 0.8073 - val_recall: 0.8018
# Epoch 73/100
# 32/32 [==============================] - 9s 276ms/step - loss: 0.2741 - accuracy: 0.9143 - precision: 0.9156 - recall: 0.9138 - val_loss: 0.5638 - val_accuracy: 0.8027 - val_precision: 0.8065 - val_recall: 0.8018
# Epoch 74/100
# 32/32 [==============================] - 9s 276ms/step - loss: 0.2692 - accuracy: 0.9177 - precision: 0.9185 - recall: 0.9165 - val_loss: 0.5620 - val_accuracy: 0.8057 - val_precision: 0.8084 - val_recall: 0.8037
# Epoch 75/100
# 32/32 [==============================] - 9s 276ms/step - loss: 0.2772 - accuracy: 0.9119 - precision: 0.9136 - recall: 0.9114 - val_loss: 0.5610 - val_accuracy: 0.8047 - val_precision: 0.8077 - val_recall: 0.8037
# Epoch 76/100
# 32/32 [==============================] - 9s 281ms/step - loss: 0.2671 - accuracy: 0.9211 - precision: 0.9222 - recall: 0.9199 - val_loss: 0.5737 - val_accuracy: 0.8027 - val_precision: 0.8047 - val_recall: 0.8008
# Epoch 77/100
# 32/32 [==============================] - 9s 282ms/step - loss: 0.2746 - accuracy: 0.9148 - precision: 0.9163 - recall: 0.9145 - val_loss: 0.5605 - val_accuracy: 0.8018 - val_precision: 0.8039 - val_recall: 0.8008
# Epoch 78/100
# 32/32 [==============================] - 9s 279ms/step - loss: 0.2740 - accuracy: 0.9167 - precision: 0.9178 - recall: 0.9158 - val_loss: 0.5514 - val_accuracy: 0.8086 - val_precision: 0.8114 - val_recall: 0.8066
# Epoch 79/100
# 32/32 [==============================] - 9s 274ms/step - loss: 0.2818 - accuracy: 0.9155 - precision: 0.9165 - recall: 0.9141 - val_loss: 0.5535 - val_accuracy: 0.8057 - val_precision: 0.8084 - val_recall: 0.8037
# Epoch 80/100
# 32/32 [==============================] - 9s 277ms/step - loss: 0.2685 - accuracy: 0.9150 - precision: 0.9157 - recall: 0.9150 - val_loss: 0.5720 - val_accuracy: 0.8018 - val_precision: 0.8037 - val_recall: 0.7998
# Epoch 81/100
# 32/32 [==============================] - 9s 280ms/step - loss: 0.2758 - accuracy: 0.9104 - precision: 0.9113 - recall: 0.9104 - val_loss: 0.5588 - val_accuracy: 0.8057 - val_precision: 0.8078 - val_recall: 0.8047
# Epoch 82/100
# 32/32 [==============================] - 9s 276ms/step - loss: 0.2668 - accuracy: 0.9204 - precision: 0.9210 - recall: 0.9192 - val_loss: 0.5620 - val_accuracy: 0.8047 - val_precision: 0.8067 - val_recall: 0.8027
# Epoch 83/100
# 32/32 [==============================] - 9s 279ms/step - loss: 0.2714 - accuracy: 0.9150 - precision: 0.9161 - recall: 0.9148 - val_loss: 0.5665 - val_accuracy: 0.8018 - val_precision: 0.8029 - val_recall: 0.7998
# Epoch 84/100
# 32/32 [==============================] - 9s 283ms/step - loss: 0.2626 - accuracy: 0.9258 - precision: 0.9272 - recall: 0.9241 - val_loss: 0.5665 - val_accuracy: 0.8047 - val_precision: 0.8057 - val_recall: 0.8018
# Epoch 85/100
# 32/32 [==============================] - 9s 281ms/step - loss: 0.2813 - accuracy: 0.9126 - precision: 0.9136 - recall: 0.9123 - val_loss: 0.5647 - val_accuracy: 0.8037 - val_precision: 0.8057 - val_recall: 0.8018
# Epoch 86/100
# 32/32 [==============================] - 9s 277ms/step - loss: 0.2768 - accuracy: 0.9158 - precision: 0.9166 - recall: 0.9153 - val_loss: 0.5561 - val_accuracy: 0.8066 - val_precision: 0.8077 - val_recall: 0.8037
# Epoch 87/100
# 32/32 [==============================] - 9s 273ms/step - loss: 0.2571 - accuracy: 0.9241 - precision: 0.9256 - recall: 0.9238 - val_loss: 0.5602 - val_accuracy: 0.8018 - val_precision: 0.8037 - val_recall: 0.7998
# Epoch 88/100
# 32/32 [==============================] - 9s 279ms/step - loss: 0.2829 - accuracy: 0.9158 - precision: 0.9177 - recall: 0.9148 - val_loss: 0.5568 - val_accuracy: 0.8066 - val_precision: 0.8086 - val_recall: 0.8047
# Epoch 89/100
# 32/32 [==============================] - 9s 276ms/step - loss: 0.2627 - accuracy: 0.9204 - precision: 0.9215 - recall: 0.9199 - val_loss: 0.5658 - val_accuracy: 0.8027 - val_precision: 0.8057 - val_recall: 0.8018
# Epoch 90/100
# 32/32 [==============================] - 9s 274ms/step - loss: 0.2883 - accuracy: 0.9109 - precision: 0.9122 - recall: 0.9104 - val_loss: 0.5586 - val_accuracy: 0.8057 - val_precision: 0.8077 - val_recall: 0.8037
# Epoch 91/100
# 32/32 [==============================] - 9s 277ms/step - loss: 0.2727 - accuracy: 0.9214 - precision: 0.9232 - recall: 0.9209 - val_loss: 0.5660 - val_accuracy: 0.8047 - val_precision: 0.8067 - val_recall: 0.8027
# Epoch 92/100
# 32/32 [==============================] - 9s 281ms/step - loss: 0.2710 - accuracy: 0.9189 - precision: 0.9198 - recall: 0.9187 - val_loss: 0.5578 - val_accuracy: 0.8037 - val_precision: 0.8065 - val_recall: 0.8018
# Epoch 93/100
# 32/32 [==============================] - 9s 283ms/step - loss: 0.2672 - accuracy: 0.9194 - precision: 0.9207 - recall: 0.9180 - val_loss: 0.5664 - val_accuracy: 0.8008 - val_precision: 0.8045 - val_recall: 0.7998
# Epoch 94/100
# 32/32 [==============================] - 9s 279ms/step - loss: 0.2790 - accuracy: 0.9106 - precision: 0.9117 - recall: 0.9101 - val_loss: 0.5555 - val_accuracy: 0.8037 - val_precision: 0.8065 - val_recall: 0.8018
# Epoch 95/100
# 32/32 [==============================] - 9s 277ms/step - loss: 0.2726 - accuracy: 0.9202 - precision: 0.9230 - recall: 0.9192 - val_loss: 0.5667 - val_accuracy: 0.8037 - val_precision: 0.8057 - val_recall: 0.8018
# Epoch 96/100
# 32/32 [==============================] - 9s 280ms/step - loss: 0.2819 - accuracy: 0.9187 - precision: 0.9205 - recall: 0.9187 - val_loss: 0.5734 - val_accuracy: 0.8008 - val_precision: 0.8027 - val_recall: 0.7988
# Epoch 97/100
# 32/32 [==============================] - 9s 283ms/step - loss: 0.2932 - accuracy: 0.9106 - precision: 0.9116 - recall: 0.9092 - val_loss: 0.5607 - val_accuracy: 0.8076 - val_precision: 0.8104 - val_recall: 0.8057
# Epoch 98/100
# 32/32 [==============================] - 9s 285ms/step - loss: 0.2784 - accuracy: 0.9189 - precision: 0.9201 - recall: 0.9172 - val_loss: 0.5693 - val_accuracy: 0.8018 - val_precision: 0.8053 - val_recall: 0.7998
# Epoch 99/100
# 32/32 [==============================] - 9s 284ms/step - loss: 0.2752 - accuracy: 0.9167 - precision: 0.9176 - recall: 0.9160 - val_loss: 0.5530 - val_accuracy: 0.8066 - val_precision: 0.8086 - val_recall: 0.8047
# Epoch 100/100
# 32/32 [==============================] - 9s 284ms/step - loss: 0.2853 - accuracy: 0.9138 - precision: 0.9160 - recall: 0.9133 - val_loss: 0.5691 - val_accuracy: 0.8037 - val_precision: 0.8065 - val_recall: 0.8018

# %%
## visualize the performance
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])
