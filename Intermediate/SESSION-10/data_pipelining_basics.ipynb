# %% [markdown]
# #### When loading the data from a local storage or from memory, the GPU can starve for data due to the potential inefficiencies manual data loaders. The tf.data API is designed to address this issue.
#
# #### A typical manual data loader is as follows (local storage)

# %%
# Class method
class DataLoader:
  def __init__(self):
    # Initialise the loader with the file paths (inputs, if lables)
    # If not label file for each input, load the label text and make a
    # input (file name): label mapping dict
    # Initialise the batch counter
    # Specify the class balancing logics if necessary
    pass
  def call(self):
    # Load a batch of input (filename): label 
    # Open the and batch the input files along with the labels
    # increament the batch counter, so next call loads the next batch
    # return the data batch
    pass

# %%
# Generator method
def dataloader():
  # Initialise the loader with the file paths (inputs, if lables)
  # If not label file for each input, load the label text and make a
  # input (file name): label mapping dict
  # Initialise the batch counter
  # Specify the class balancing logics if necessary
  def datagenerator():
    # yield each batch given the batch size and increament the batch counter
    databatch = None
    yield databatch
  
  return datagenerator

# %% [markdown]
# #### However the tf.data API allows one to build more complex data pipelines using reusable simple set of APIs

# %%
import tensorflow as tf
import numpy as np

# %%
# Simple dataset (memory)
simple_dataset_1 = tf.data.Dataset.from_tensor_slices([5, 3, 2, 1, 6, 8])
for i in simple_dataset_1:
  print(i)
# Out:
# tf.Tensor(5, shape=(), dtype=int32)
# tf.Tensor(3, shape=(), dtype=int32)
# tf.Tensor(2, shape=(), dtype=int32)
# tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(6, shape=(), dtype=int32)
# tf.Tensor(8, shape=(), dtype=int32)

# %%
# Simple dataset with label association
simple_dataset_2 = tf.data.Dataset.from_tensor_slices(([5, 3, 2, 1, 6, 8], ["a", "b", "c", "d", "e", "f"]))
for i, j in simple_dataset_2:
  print("input: {}, label: {}".format(i, j))
# Out:
# input: 5, label: b'a'
# input: 3, label: b'b'
# input: 2, label: b'c'
# input: 1, label: b'd'
# input: 6, label: b'e'
# input: 8, label: b'f'

# %% [markdown]
# #### Additionally, typical python like functional methods are available to perform transformations such as map, reduce and filter

# %%
# map to transform element wise
simple_dataset_map = simple_dataset_2.map(lambda x, y: (x**2, y))
for i, j in simple_dataset_map:
  print("input: {}, label: {}".format(i, j))
# Out:
# input: 25, label: b'a'
# input: 9, label: b'b'
# input: 4, label: b'c'
# input: 1, label: b'd'
# input: 36, label: b'e'
# input: 64, label: b'f'

# %%
# Reduce a tensor to a single value
simple_dataset_reduce = simple_dataset_1.reduce(np.int32(0), lambda x,y: x+y).numpy()
print(simple_dataset_reduce)
# Out:
# 25

# %%
# Filter unnecessary values
'''
def filter_fn(ds):
  return ds.filter(lambda x: x < 3)

simple_dataset_filter = simple_dataset_2.apply(filter_fn)
'''
simple_dataset_filter = simple_dataset_2.filter(lambda x, y: x>=3)
for i, j in simple_dataset_filter:
  print("input: {}, label: {}".format(i, j))
# Out:
# input: 5, label: b'a'
# input: 3, label: b'b'
# input: 6, label: b'e'
# input: 8, label: b'f'

# %% [markdown]
# #### A python generator can be converted into a tf dataset

# %%
def get_generator():
  data = tf.random.uniform((1000, 1))
  def simple_generator(stop):
    i = 0
    while i < stop:
      elem = data[i]
      i += 1
      yield elem
    
  return simple_generator

# %%
# Python approach
my_generator = get_generator()
for i in my_generator(1000):
  print(i)
# Out:
# tf.Tensor([0.16083467], shape=(1,), dtype=float32)
# tf.Tensor([0.4409504], shape=(1,), dtype=float32)
# tf.Tensor([0.28390074], shape=(1,), dtype=float32)
# tf.Tensor([0.31091225], shape=(1,), dtype=float32)
# tf.Tensor([0.6245127], shape=(1,), dtype=float32)
# tf.Tensor([0.1452483], shape=(1,), dtype=float32)
# tf.Tensor([0.81280386], shape=(1,), dtype=float32)
# tf.Tensor([0.7549505], shape=(1,), dtype=float32)
# tf.Tensor([0.87484515], shape=(1,), dtype=float32)
# tf.Tensor([0.32321012], shape=(1,), dtype=float32)
# tf.Tensor([0.172256], shape=(1,), dtype=float32)
# tf.Tensor([0.52800465], shape=(1,), dtype=float32)
# tf.Tensor([0.16079545], shape=(1,), dtype=float32)
# tf.Tensor([0.17790401], shape=(1,), dtype=float32)
# tf.Tensor([0.64372504], shape=(1,), dtype=float32)
# tf.Tensor([0.6612303], shape=(1,), dtype=float32)
# tf.Tensor([0.351529], shape=(1,), dtype=float32)
# tf.Tensor([0.64212215], shape=(1,), dtype=float32)
# tf.Tensor([0.8795152], shape=(1,), dtype=float32)
# tf.Tensor([0.37303734], shape=(1,), dtype=float32)
# tf.Tensor([0.65413797], shape=(1,), dtype=float32)
# tf.Tensor([0.09908831], shape=(1,), dtype=float32)
# tf.Tensor([0.32144654], shape=(1,), dtype=float32)
# tf.Tensor([0.68531466], shape=(1,), dtype=float32)
# tf.Tensor([0.28770924], shape=(1,), dtype=float32)
# tf.Tensor([0.8808857], shape=(1,), dtype=float32)
# tf.Tensor([0.91681015], shape=(1,), dtype=float32)
# tf.Tensor([0.2883761], shape=(1,), dtype=float32)
# tf.Tensor([0.82795703], shape=(1,), dtype=float32)
# tf.Tensor([0.60646725], shape=(1,), dtype=float32)
# tf.Tensor([0.33460736], shape=(1,), dtype=float32)
# tf.Tensor([0.96000373], shape=(1,), dtype=float32)
# tf.Tensor([0.46340024], shape=(1,), dtype=float32)
# tf.Tensor([0.9240588], shape=(1,), dtype=float32)
# tf.Tensor([0.2875607], shape=(1,), dtype=float32)
# tf.Tensor([0.80893123], shape=(1,), dtype=float32)
# tf.Tensor([0.06501162], shape=(1,), dtype=float32)
# tf.Tensor([0.06923485], shape=(1,), dtype=float32)
# tf.Tensor([0.5056788], shape=(1,), dtype=float32)
# tf.Tensor([0.05903137], shape=(1,), dtype=float32)
# tf.Tensor([0.99903095], shape=(1,), dtype=float32)
# tf.Tensor([0.02457964], shape=(1,), dtype=float32)
# tf.Tensor([0.4107095], shape=(1,), dtype=float32)
# tf.Tensor([0.45208228], shape=(1,), dtype=float32)
# tf.Tensor([0.8538363], shape=(1,), dtype=float32)
# tf.Tensor([0.53129196], shape=(1,), dtype=float32)
# tf.Tensor([0.61314106], shape=(1,), dtype=float32)
# tf.Tensor([0.50105524], shape=(1,), dtype=float32)
# tf.Tensor([0.58193994], shape=(1,), dtype=float32)
# tf.Tensor([0.17133975], shape=(1,), dtype=float32)
# tf.Tensor([0.30836904], shape=(1,), dtype=float32)
# tf.Tensor([0.386837], shape=(1,), dtype=float32)
# tf.Tensor([0.51339734], shape=(1,), dtype=float32)
# tf.Tensor([0.5141263], shape=(1,), dtype=float32)
# tf.Tensor([0.14858496], shape=(1,), dtype=float32)
# tf.Tensor([0.39838493], shape=(1,), dtype=float32)
# tf.Tensor([0.6155671], shape=(1,), dtype=float32)
# tf.Tensor([0.3745072], shape=(1,), dtype=float32)
# tf.Tensor([0.26848054], shape=(1,), dtype=float32)
# tf.Tensor([0.07346356], shape=(1,), dtype=float32)
# tf.Tensor([0.19277644], shape=(1,), dtype=float32)
# tf.Tensor([0.9991056], shape=(1,), dtype=float32)
# tf.Tensor([0.72576225], shape=(1,), dtype=float32)
# tf.Tensor([0.79581785], shape=(1,), dtype=float32)
# tf.Tensor([0.42185378], shape=(1,), dtype=float32)
# tf.Tensor([0.98812985], shape=(1,), dtype=float32)
# tf.Tensor([0.7914159], shape=(1,), dtype=float32)
# tf.Tensor([0.32639635], shape=(1,), dtype=float32)
# tf.Tensor([0.6550745], shape=(1,), dtype=float32)
# tf.Tensor([0.8329582], shape=(1,), dtype=float32)
# tf.Tensor([0.17259955], shape=(1,), dtype=float32)
# tf.Tensor([0.41346073], shape=(1,), dtype=float32)
# tf.Tensor([0.07222807], shape=(1,), dtype=float32)
# tf.Tensor([0.20675254], shape=(1,), dtype=float32)
# tf.Tensor([0.7544439], shape=(1,), dtype=float32)
# tf.Tensor([0.33152044], shape=(1,), dtype=float32)
# tf.Tensor([0.9612992], shape=(1,), dtype=float32)
# tf.Tensor([0.0589124], shape=(1,), dtype=float32)
# tf.Tensor([0.0323236], shape=(1,), dtype=float32)
# tf.Tensor([0.32399464], shape=(1,), dtype=float32)
# tf.Tensor([0.5513743], shape=(1,), dtype=float32)
# tf.Tensor([0.01932776], shape=(1,), dtype=float32)
# tf.Tensor([0.93767715], shape=(1,), dtype=float32)
# tf.Tensor([0.67951214], shape=(1,), dtype=float32)
# tf.Tensor([0.37463748], shape=(1,), dtype=float32)
# tf.Tensor([0.14092326], shape=(1,), dtype=float32)
# tf.Tensor([0.8846154], shape=(1,), dtype=float32)
# tf.Tensor([0.7130885], shape=(1,), dtype=float32)
# tf.Tensor([0.5277928], shape=(1,), dtype=float32)
# tf.Tensor([0.9921886], shape=(1,), dtype=float32)
# tf.Tensor([0.61561024], shape=(1,), dtype=float32)
# tf.Tensor([0.79993916], shape=(1,), dtype=float32)
# tf.Tensor([0.9253119], shape=(1,), dtype=float32)
# tf.Tensor([0.71278584], shape=(1,), dtype=float32)
# tf.Tensor([0.6219579], shape=(1,), dtype=float32)
# tf.Tensor([0.05281448], shape=(1,), dtype=float32)
# tf.Tensor([0.31322908], shape=(1,), dtype=float32)
# tf.Tensor([0.7793437], shape=(1,), dtype=float32)
# tf.Tensor([0.14995337], shape=(1,), dtype=float32)
# tf.Tensor([0.6144285], shape=(1,), dtype=float32)
# tf.Tensor([0.1544596], shape=(1,), dtype=float32)
# tf.Tensor([0.4304912], shape=(1,), dtype=float32)
# tf.Tensor([0.41877985], shape=(1,), dtype=float32)
# tf.Tensor([0.3346746], shape=(1,), dtype=float32)
# tf.Tensor([0.00733376], shape=(1,), dtype=float32)
# tf.Tensor([0.5922296], shape=(1,), dtype=float32)
# tf.Tensor([0.06376243], shape=(1,), dtype=float32)
# tf.Tensor([0.9578103], shape=(1,), dtype=float32)
# tf.Tensor([0.52347267], shape=(1,), dtype=float32)
# tf.Tensor([0.6251912], shape=(1,), dtype=float32)
# tf.Tensor([0.14243937], shape=(1,), dtype=float32)
# tf.Tensor([0.7536138], shape=(1,), dtype=float32)
# tf.Tensor([0.12941968], shape=(1,), dtype=float32)
# tf.Tensor([0.05273533], shape=(1,), dtype=float32)
# tf.Tensor([0.50428843], shape=(1,), dtype=float32)
# tf.Tensor([0.6184033], shape=(1,), dtype=float32)
# tf.Tensor([0.03225636], shape=(1,), dtype=float32)
# tf.Tensor([0.6419344], shape=(1,), dtype=float32)
# tf.Tensor([0.8531221], shape=(1,), dtype=float32)
# tf.Tensor([0.7317376], shape=(1,), dtype=float32)
# tf.Tensor([0.60398185], shape=(1,), dtype=float32)
# tf.Tensor([0.4137709], shape=(1,), dtype=float32)
# tf.Tensor([0.08887017], shape=(1,), dtype=float32)
# tf.Tensor([0.41254616], shape=(1,), dtype=float32)
# tf.Tensor([0.22417486], shape=(1,), dtype=float32)
# tf.Tensor([0.7878045], shape=(1,), dtype=float32)
# tf.Tensor([0.8971952], shape=(1,), dtype=float32)
# tf.Tensor([0.229262], shape=(1,), dtype=float32)
# tf.Tensor([0.17537117], shape=(1,), dtype=float32)
# tf.Tensor([0.5875597], shape=(1,), dtype=float32)
# tf.Tensor([0.4594413], shape=(1,), dtype=float32)
# tf.Tensor([0.6992003], shape=(1,), dtype=float32)
# tf.Tensor([0.4205767], shape=(1,), dtype=float32)
# tf.Tensor([0.10331166], shape=(1,), dtype=float32)
# tf.Tensor([0.38545823], shape=(1,), dtype=float32)
# tf.Tensor([0.33143425], shape=(1,), dtype=float32)
# tf.Tensor([0.56825113], shape=(1,), dtype=float32)
# tf.Tensor([0.22154725], shape=(1,), dtype=float32)
# tf.Tensor([0.3906002], shape=(1,), dtype=float32)
# tf.Tensor([0.98738754], shape=(1,), dtype=float32)
# tf.Tensor([0.360978], shape=(1,), dtype=float32)
# tf.Tensor([0.59879947], shape=(1,), dtype=float32)
# tf.Tensor([0.35276628], shape=(1,), dtype=float32)
# tf.Tensor([0.1954062], shape=(1,), dtype=float32)
# tf.Tensor([0.01234853], shape=(1,), dtype=float32)
# tf.Tensor([0.8107686], shape=(1,), dtype=float32)
# tf.Tensor([0.8996537], shape=(1,), dtype=float32)
# tf.Tensor([0.5087341], shape=(1,), dtype=float32)
# tf.Tensor([0.08154047], shape=(1,), dtype=float32)
# tf.Tensor([0.7990211], shape=(1,), dtype=float32)
# tf.Tensor([0.6254846], shape=(1,), dtype=float32)
# tf.Tensor([0.07732332], shape=(1,), dtype=float32)
# tf.Tensor([0.4070499], shape=(1,), dtype=float32)
# tf.Tensor([0.7735654], shape=(1,), dtype=float32)
# tf.Tensor([0.30039895], shape=(1,), dtype=float32)
# tf.Tensor([0.14483964], shape=(1,), dtype=float32)
# tf.Tensor([0.6302204], shape=(1,), dtype=float32)
# tf.Tensor([0.56097996], shape=(1,), dtype=float32)
# tf.Tensor([0.54931796], shape=(1,), dtype=float32)
# tf.Tensor([0.8711227], shape=(1,), dtype=float32)
# tf.Tensor([0.6754669], shape=(1,), dtype=float32)
# tf.Tensor([0.4160862], shape=(1,), dtype=float32)
# tf.Tensor([0.43093884], shape=(1,), dtype=float32)
# tf.Tensor([0.82496893], shape=(1,), dtype=float32)
# tf.Tensor([0.94780254], shape=(1,), dtype=float32)
# tf.Tensor([0.6624905], shape=(1,), dtype=float32)
# tf.Tensor([0.04484797], shape=(1,), dtype=float32)
# tf.Tensor([0.3930534], shape=(1,), dtype=float32)
# tf.Tensor([0.3855772], shape=(1,), dtype=float32)
# tf.Tensor([0.77093124], shape=(1,), dtype=float32)
# tf.Tensor([0.4757886], shape=(1,), dtype=float32)
# tf.Tensor([0.04355752], shape=(1,), dtype=float32)
# tf.Tensor([0.4564401], shape=(1,), dtype=float32)
# tf.Tensor([0.3686887], shape=(1,), dtype=float32)
# tf.Tensor([0.2529751], shape=(1,), dtype=float32)
# tf.Tensor([0.34537995], shape=(1,), dtype=float32)
# tf.Tensor([0.47579098], shape=(1,), dtype=float32)
# tf.Tensor([0.3353511], shape=(1,), dtype=float32)
# tf.Tensor([0.44331086], shape=(1,), dtype=float32)
# tf.Tensor([0.9714949], shape=(1,), dtype=float32)
# tf.Tensor([0.14735353], shape=(1,), dtype=float32)
# tf.Tensor([0.51587486], shape=(1,), dtype=float32)
# tf.Tensor([0.70905995], shape=(1,), dtype=float32)
# tf.Tensor([0.00665212], shape=(1,), dtype=float32)
# tf.Tensor([0.25777233], shape=(1,), dtype=float32)
# tf.Tensor([0.7936423], shape=(1,), dtype=float32)
# tf.Tensor([0.07939088], shape=(1,), dtype=float32)
# tf.Tensor([0.7719002], shape=(1,), dtype=float32)
# tf.Tensor([0.03548622], shape=(1,), dtype=float32)
# tf.Tensor([0.49325776], shape=(1,), dtype=float32)
# tf.Tensor([0.9402199], shape=(1,), dtype=float32)
# tf.Tensor([0.08125186], shape=(1,), dtype=float32)
# tf.Tensor([0.41383886], shape=(1,), dtype=float32)
# tf.Tensor([0.5561421], shape=(1,), dtype=float32)
# tf.Tensor([0.8198477], shape=(1,), dtype=float32)
# tf.Tensor([0.7423408], shape=(1,), dtype=float32)
# tf.Tensor([0.40603638], shape=(1,), dtype=float32)
# tf.Tensor([0.93812454], shape=(1,), dtype=float32)
# tf.Tensor([0.29681885], shape=(1,), dtype=float32)
# tf.Tensor([0.8274044], shape=(1,), dtype=float32)
# tf.Tensor([0.3907286], shape=(1,), dtype=float32)
# tf.Tensor([0.4904176], shape=(1,), dtype=float32)
# tf.Tensor([0.09396577], shape=(1,), dtype=float32)
# tf.Tensor([0.7431493], shape=(1,), dtype=float32)
# tf.Tensor([0.38177884], shape=(1,), dtype=float32)
# tf.Tensor([0.8969662], shape=(1,), dtype=float32)
# tf.Tensor([0.84060776], shape=(1,), dtype=float32)
# tf.Tensor([0.65670633], shape=(1,), dtype=float32)
# tf.Tensor([0.5867245], shape=(1,), dtype=float32)
# tf.Tensor([0.62160885], shape=(1,), dtype=float32)
# tf.Tensor([0.74953604], shape=(1,), dtype=float32)
# tf.Tensor([0.59992456], shape=(1,), dtype=float32)
# tf.Tensor([0.01117206], shape=(1,), dtype=float32)
# tf.Tensor([0.8106109], shape=(1,), dtype=float32)
# tf.Tensor([0.17785466], shape=(1,), dtype=float32)
# tf.Tensor([0.29618192], shape=(1,), dtype=float32)
# tf.Tensor([0.1891663], shape=(1,), dtype=float32)
# tf.Tensor([0.24358773], shape=(1,), dtype=float32)
# tf.Tensor([0.5562991], shape=(1,), dtype=float32)
# tf.Tensor([0.4834776], shape=(1,), dtype=float32)
# tf.Tensor([0.19514632], shape=(1,), dtype=float32)
# tf.Tensor([0.69106114], shape=(1,), dtype=float32)
# tf.Tensor([0.35713542], shape=(1,), dtype=float32)
# tf.Tensor([0.14552796], shape=(1,), dtype=float32)
# tf.Tensor([0.91187286], shape=(1,), dtype=float32)
# tf.Tensor([0.01001048], shape=(1,), dtype=float32)
# tf.Tensor([0.65651643], shape=(1,), dtype=float32)
# tf.Tensor([0.54119205], shape=(1,), dtype=float32)
# tf.Tensor([0.44777918], shape=(1,), dtype=float32)
# tf.Tensor([0.56529915], shape=(1,), dtype=float32)
# tf.Tensor([0.5165113], shape=(1,), dtype=float32)
# tf.Tensor([0.70511186], shape=(1,), dtype=float32)
# tf.Tensor([0.5870632], shape=(1,), dtype=float32)
# tf.Tensor([0.89853394], shape=(1,), dtype=float32)
# tf.Tensor([0.6284882], shape=(1,), dtype=float32)
# tf.Tensor([0.9215863], shape=(1,), dtype=float32)
# tf.Tensor([0.05590999], shape=(1,), dtype=float32)
# tf.Tensor([0.44592512], shape=(1,), dtype=float32)
# tf.Tensor([0.72947454], shape=(1,), dtype=float32)
# tf.Tensor([0.40024102], shape=(1,), dtype=float32)
# tf.Tensor([0.2994907], shape=(1,), dtype=float32)
# tf.Tensor([0.5506742], shape=(1,), dtype=float32)
# tf.Tensor([0.36375856], shape=(1,), dtype=float32)
# tf.Tensor([0.30711687], shape=(1,), dtype=float32)
# tf.Tensor([0.86792254], shape=(1,), dtype=float32)
# tf.Tensor([0.6492038], shape=(1,), dtype=float32)
# tf.Tensor([0.79921675], shape=(1,), dtype=float32)
# tf.Tensor([0.5054791], shape=(1,), dtype=float32)
# tf.Tensor([0.36512327], shape=(1,), dtype=float32)
# tf.Tensor([0.22380066], shape=(1,), dtype=float32)
# tf.Tensor([0.9185045], shape=(1,), dtype=float32)
# tf.Tensor([0.88883436], shape=(1,), dtype=float32)
# tf.Tensor([0.83480954], shape=(1,), dtype=float32)
# tf.Tensor([0.88364446], shape=(1,), dtype=float32)
# tf.Tensor([0.44754875], shape=(1,), dtype=float32)
# tf.Tensor([0.57025504], shape=(1,), dtype=float32)
# tf.Tensor([0.12588704], shape=(1,), dtype=float32)
# tf.Tensor([0.05617833], shape=(1,), dtype=float32)
# tf.Tensor([0.31042743], shape=(1,), dtype=float32)
# tf.Tensor([0.08826268], shape=(1,), dtype=float32)
# tf.Tensor([0.24121964], shape=(1,), dtype=float32)
# tf.Tensor([0.51142526], shape=(1,), dtype=float32)
# tf.Tensor([0.8347243], shape=(1,), dtype=float32)
# tf.Tensor([0.47906864], shape=(1,), dtype=float32)
# tf.Tensor([0.18017411], shape=(1,), dtype=float32)
# tf.Tensor([0.58145845], shape=(1,), dtype=float32)
# tf.Tensor([0.06575251], shape=(1,), dtype=float32)
# tf.Tensor([0.11558247], shape=(1,), dtype=float32)
# tf.Tensor([0.48763943], shape=(1,), dtype=float32)
# tf.Tensor([0.47059703], shape=(1,), dtype=float32)
# tf.Tensor([0.64814436], shape=(1,), dtype=float32)
# tf.Tensor([0.29945683], shape=(1,), dtype=float32)
# tf.Tensor([0.6041031], shape=(1,), dtype=float32)
# tf.Tensor([0.67404246], shape=(1,), dtype=float32)
# tf.Tensor([0.325109], shape=(1,), dtype=float32)
# tf.Tensor([0.4789021], shape=(1,), dtype=float32)
# tf.Tensor([0.46565425], shape=(1,), dtype=float32)
# tf.Tensor([0.47761345], shape=(1,), dtype=float32)
# tf.Tensor([0.28607976], shape=(1,), dtype=float32)
# tf.Tensor([0.24103737], shape=(1,), dtype=float32)
# tf.Tensor([0.5303383], shape=(1,), dtype=float32)
# tf.Tensor([0.2615924], shape=(1,), dtype=float32)
# tf.Tensor([0.29880655], shape=(1,), dtype=float32)
# tf.Tensor([0.08343923], shape=(1,), dtype=float32)
# tf.Tensor([0.16957164], shape=(1,), dtype=float32)
# tf.Tensor([0.30130208], shape=(1,), dtype=float32)
# tf.Tensor([0.54500866], shape=(1,), dtype=float32)
# tf.Tensor([0.9059037], shape=(1,), dtype=float32)
# tf.Tensor([0.5153247], shape=(1,), dtype=float32)
# tf.Tensor([0.80460155], shape=(1,), dtype=float32)
# tf.Tensor([0.49526143], shape=(1,), dtype=float32)
# tf.Tensor([0.8161862], shape=(1,), dtype=float32)
# tf.Tensor([0.35961807], shape=(1,), dtype=float32)
# tf.Tensor([0.7759495], shape=(1,), dtype=float32)
# tf.Tensor([0.31505227], shape=(1,), dtype=float32)
# tf.Tensor([0.35491145], shape=(1,), dtype=float32)
# tf.Tensor([0.47552013], shape=(1,), dtype=float32)
# tf.Tensor([0.8476896], shape=(1,), dtype=float32)
# tf.Tensor([0.24216604], shape=(1,), dtype=float32)
# tf.Tensor([0.2566836], shape=(1,), dtype=float32)
# tf.Tensor([0.21395993], shape=(1,), dtype=float32)
# tf.Tensor([0.08601069], shape=(1,), dtype=float32)
# tf.Tensor([0.33047056], shape=(1,), dtype=float32)
# tf.Tensor([0.06353557], shape=(1,), dtype=float32)
# tf.Tensor([0.61404955], shape=(1,), dtype=float32)
# tf.Tensor([0.06698704], shape=(1,), dtype=float32)
# tf.Tensor([0.9043653], shape=(1,), dtype=float32)
# tf.Tensor([0.9601296], shape=(1,), dtype=float32)
# tf.Tensor([0.8290744], shape=(1,), dtype=float32)
# tf.Tensor([0.0124917], shape=(1,), dtype=float32)
# tf.Tensor([0.3192824], shape=(1,), dtype=float32)
# tf.Tensor([0.5699512], shape=(1,), dtype=float32)
# tf.Tensor([0.15754187], shape=(1,), dtype=float32)
# tf.Tensor([0.6434244], shape=(1,), dtype=float32)
# tf.Tensor([0.20663404], shape=(1,), dtype=float32)
# tf.Tensor([0.5923835], shape=(1,), dtype=float32)
# tf.Tensor([0.82421684], shape=(1,), dtype=float32)
# tf.Tensor([0.00619078], shape=(1,), dtype=float32)
# tf.Tensor([0.6449938], shape=(1,), dtype=float32)
# tf.Tensor([0.4742918], shape=(1,), dtype=float32)
# tf.Tensor([0.25473893], shape=(1,), dtype=float32)
# tf.Tensor([0.4267311], shape=(1,), dtype=float32)
# tf.Tensor([0.3088236], shape=(1,), dtype=float32)
# tf.Tensor([0.38495278], shape=(1,), dtype=float32)
# tf.Tensor([0.0772692], shape=(1,), dtype=float32)
# tf.Tensor([0.9021095], shape=(1,), dtype=float32)
# tf.Tensor([0.53719103], shape=(1,), dtype=float32)
# tf.Tensor([0.68818593], shape=(1,), dtype=float32)
# tf.Tensor([0.04128683], shape=(1,), dtype=float32)
# tf.Tensor([0.16955972], shape=(1,), dtype=float32)
# tf.Tensor([0.6779257], shape=(1,), dtype=float32)
# tf.Tensor([0.05195761], shape=(1,), dtype=float32)
# tf.Tensor([0.16435587], shape=(1,), dtype=float32)
# tf.Tensor([0.9766458], shape=(1,), dtype=float32)
# tf.Tensor([0.82564056], shape=(1,), dtype=float32)
# tf.Tensor([0.1806407], shape=(1,), dtype=float32)
# tf.Tensor([0.8551061], shape=(1,), dtype=float32)
# tf.Tensor([0.12337685], shape=(1,), dtype=float32)
# tf.Tensor([0.91094315], shape=(1,), dtype=float32)
# tf.Tensor([0.77980363], shape=(1,), dtype=float32)
# tf.Tensor([0.82177603], shape=(1,), dtype=float32)
# tf.Tensor([0.29033732], shape=(1,), dtype=float32)
# tf.Tensor([0.59995675], shape=(1,), dtype=float32)
# tf.Tensor([0.24216878], shape=(1,), dtype=float32)
# tf.Tensor([0.35692227], shape=(1,), dtype=float32)
# tf.Tensor([0.66505194], shape=(1,), dtype=float32)
# tf.Tensor([0.22830844], shape=(1,), dtype=float32)
# tf.Tensor([0.65332913], shape=(1,), dtype=float32)
# tf.Tensor([0.15362084], shape=(1,), dtype=float32)
# tf.Tensor([0.25651073], shape=(1,), dtype=float32)
# tf.Tensor([0.9977517], shape=(1,), dtype=float32)
# tf.Tensor([0.52526176], shape=(1,), dtype=float32)
# tf.Tensor([0.73997474], shape=(1,), dtype=float32)
# tf.Tensor([0.36248386], shape=(1,), dtype=float32)
# tf.Tensor([0.36230767], shape=(1,), dtype=float32)
# tf.Tensor([0.37618053], shape=(1,), dtype=float32)
# tf.Tensor([0.26750267], shape=(1,), dtype=float32)
# tf.Tensor([0.38539386], shape=(1,), dtype=float32)
# tf.Tensor([0.6869767], shape=(1,), dtype=float32)
# tf.Tensor([0.8321333], shape=(1,), dtype=float32)
# tf.Tensor([0.6550348], shape=(1,), dtype=float32)
# tf.Tensor([0.67967916], shape=(1,), dtype=float32)
# tf.Tensor([0.38475323], shape=(1,), dtype=float32)
# tf.Tensor([0.04271305], shape=(1,), dtype=float32)
# tf.Tensor([0.21157622], shape=(1,), dtype=float32)
# tf.Tensor([0.31818128], shape=(1,), dtype=float32)
# tf.Tensor([0.6068407], shape=(1,), dtype=float32)
# tf.Tensor([0.30507517], shape=(1,), dtype=float32)
# tf.Tensor([0.16958928], shape=(1,), dtype=float32)
# tf.Tensor([0.2047255], shape=(1,), dtype=float32)
# tf.Tensor([0.9335104], shape=(1,), dtype=float32)
# tf.Tensor([0.46477365], shape=(1,), dtype=float32)
# tf.Tensor([0.7996713], shape=(1,), dtype=float32)
# tf.Tensor([0.6359967], shape=(1,), dtype=float32)
# tf.Tensor([0.60861444], shape=(1,), dtype=float32)
# tf.Tensor([0.41554546], shape=(1,), dtype=float32)
# tf.Tensor([0.85208774], shape=(1,), dtype=float32)
# tf.Tensor([0.5085585], shape=(1,), dtype=float32)
# tf.Tensor([0.8922161], shape=(1,), dtype=float32)
# tf.Tensor([0.88623464], shape=(1,), dtype=float32)
# tf.Tensor([0.24524677], shape=(1,), dtype=float32)
# tf.Tensor([0.42274952], shape=(1,), dtype=float32)
# tf.Tensor([0.7335354], shape=(1,), dtype=float32)
# tf.Tensor([0.45490623], shape=(1,), dtype=float32)
# tf.Tensor([0.40084696], shape=(1,), dtype=float32)
# tf.Tensor([0.86403286], shape=(1,), dtype=float32)
# tf.Tensor([0.53360903], shape=(1,), dtype=float32)
# tf.Tensor([0.8921975], shape=(1,), dtype=float32)
# tf.Tensor([0.6689453], shape=(1,), dtype=float32)
# tf.Tensor([0.2200011], shape=(1,), dtype=float32)
# tf.Tensor([0.23915482], shape=(1,), dtype=float32)
# tf.Tensor([0.20273256], shape=(1,), dtype=float32)
# tf.Tensor([0.8836204], shape=(1,), dtype=float32)
# tf.Tensor([0.648487], shape=(1,), dtype=float32)
# tf.Tensor([0.8468877], shape=(1,), dtype=float32)
# tf.Tensor([0.44545555], shape=(1,), dtype=float32)
# tf.Tensor([0.83682466], shape=(1,), dtype=float32)
# tf.Tensor([0.7789011], shape=(1,), dtype=float32)
# tf.Tensor([0.5530888], shape=(1,), dtype=float32)
# tf.Tensor([0.5178125], shape=(1,), dtype=float32)
# tf.Tensor([0.9777441], shape=(1,), dtype=float32)
# tf.Tensor([0.15768564], shape=(1,), dtype=float32)
# tf.Tensor([0.4871254], shape=(1,), dtype=float32)
# tf.Tensor([0.39165294], shape=(1,), dtype=float32)
# tf.Tensor([0.10972035], shape=(1,), dtype=float32)
# tf.Tensor([0.3376304], shape=(1,), dtype=float32)
# tf.Tensor([0.49260533], shape=(1,), dtype=float32)
# tf.Tensor([0.8518188], shape=(1,), dtype=float32)
# tf.Tensor([0.5298383], shape=(1,), dtype=float32)
# tf.Tensor([0.6116152], shape=(1,), dtype=float32)
# tf.Tensor([0.35055256], shape=(1,), dtype=float32)
# tf.Tensor([0.16392756], shape=(1,), dtype=float32)
# tf.Tensor([0.28428698], shape=(1,), dtype=float32)
# tf.Tensor([0.10503268], shape=(1,), dtype=float32)
# tf.Tensor([0.59272075], shape=(1,), dtype=float32)
# tf.Tensor([0.7247963], shape=(1,), dtype=float32)
# tf.Tensor([0.39384413], shape=(1,), dtype=float32)
# tf.Tensor([0.5444834], shape=(1,), dtype=float32)
# tf.Tensor([0.7238134], shape=(1,), dtype=float32)
# tf.Tensor([0.6730114], shape=(1,), dtype=float32)
# tf.Tensor([0.87547565], shape=(1,), dtype=float32)
# tf.Tensor([0.90151095], shape=(1,), dtype=float32)
# tf.Tensor([0.16564095], shape=(1,), dtype=float32)
# tf.Tensor([0.24264967], shape=(1,), dtype=float32)
# tf.Tensor([0.7500311], shape=(1,), dtype=float32)
# tf.Tensor([0.976575], shape=(1,), dtype=float32)
# tf.Tensor([0.8856076], shape=(1,), dtype=float32)
# tf.Tensor([0.1934241], shape=(1,), dtype=float32)
# tf.Tensor([0.18796396], shape=(1,), dtype=float32)
# tf.Tensor([0.56919503], shape=(1,), dtype=float32)
# tf.Tensor([0.3678038], shape=(1,), dtype=float32)
# tf.Tensor([0.8474499], shape=(1,), dtype=float32)
# tf.Tensor([0.48640072], shape=(1,), dtype=float32)
# tf.Tensor([0.04145122], shape=(1,), dtype=float32)
# tf.Tensor([0.99708974], shape=(1,), dtype=float32)
# tf.Tensor([0.9454205], shape=(1,), dtype=float32)
# tf.Tensor([0.5761719], shape=(1,), dtype=float32)
# tf.Tensor([0.20342481], shape=(1,), dtype=float32)
# tf.Tensor([0.2931466], shape=(1,), dtype=float32)
# tf.Tensor([0.974051], shape=(1,), dtype=float32)
# tf.Tensor([0.65287244], shape=(1,), dtype=float32)
# tf.Tensor([0.18939757], shape=(1,), dtype=float32)
# tf.Tensor([0.26867592], shape=(1,), dtype=float32)
# tf.Tensor([0.5403223], shape=(1,), dtype=float32)
# tf.Tensor([0.04393327], shape=(1,), dtype=float32)
# tf.Tensor([0.65546346], shape=(1,), dtype=float32)
# tf.Tensor([0.5655216], shape=(1,), dtype=float32)
# tf.Tensor([0.9251175], shape=(1,), dtype=float32)
# tf.Tensor([0.00161219], shape=(1,), dtype=float32)
# tf.Tensor([0.30082083], shape=(1,), dtype=float32)
# tf.Tensor([0.47917688], shape=(1,), dtype=float32)
# tf.Tensor([0.89312565], shape=(1,), dtype=float32)
# tf.Tensor([0.6039244], shape=(1,), dtype=float32)
# tf.Tensor([0.7721571], shape=(1,), dtype=float32)
# tf.Tensor([0.581056], shape=(1,), dtype=float32)
# tf.Tensor([0.23852193], shape=(1,), dtype=float32)
# tf.Tensor([0.5824684], shape=(1,), dtype=float32)
# tf.Tensor([0.86549556], shape=(1,), dtype=float32)
# tf.Tensor([0.60140574], shape=(1,), dtype=float32)
# tf.Tensor([0.66786003], shape=(1,), dtype=float32)
# tf.Tensor([0.44991016], shape=(1,), dtype=float32)
# tf.Tensor([0.35363662], shape=(1,), dtype=float32)
# tf.Tensor([0.5882293], shape=(1,), dtype=float32)
# tf.Tensor([0.47217917], shape=(1,), dtype=float32)
# tf.Tensor([0.53592384], shape=(1,), dtype=float32)
# tf.Tensor([0.9858947], shape=(1,), dtype=float32)
# tf.Tensor([0.9404267], shape=(1,), dtype=float32)
# tf.Tensor([0.6284368], shape=(1,), dtype=float32)
# tf.Tensor([0.7031697], shape=(1,), dtype=float32)
# tf.Tensor([0.05438936], shape=(1,), dtype=float32)
# tf.Tensor([0.65358233], shape=(1,), dtype=float32)
# tf.Tensor([0.70085776], shape=(1,), dtype=float32)
# tf.Tensor([0.63265455], shape=(1,), dtype=float32)
# tf.Tensor([0.8658421], shape=(1,), dtype=float32)
# tf.Tensor([0.7642329], shape=(1,), dtype=float32)
# tf.Tensor([0.5803355], shape=(1,), dtype=float32)
# tf.Tensor([0.6047349], shape=(1,), dtype=float32)
# tf.Tensor([0.33922887], shape=(1,), dtype=float32)
# tf.Tensor([0.5471413], shape=(1,), dtype=float32)
# tf.Tensor([0.6850797], shape=(1,), dtype=float32)
# tf.Tensor([0.9727261], shape=(1,), dtype=float32)
# tf.Tensor([0.95972], shape=(1,), dtype=float32)
# tf.Tensor([0.5582032], shape=(1,), dtype=float32)
# tf.Tensor([0.5020131], shape=(1,), dtype=float32)
# tf.Tensor([0.1826508], shape=(1,), dtype=float32)
# tf.Tensor([0.4291588], shape=(1,), dtype=float32)
# tf.Tensor([0.880378], shape=(1,), dtype=float32)
# tf.Tensor([0.80723083], shape=(1,), dtype=float32)
# tf.Tensor([0.6973531], shape=(1,), dtype=float32)
# tf.Tensor([0.2882576], shape=(1,), dtype=float32)
# tf.Tensor([0.7836131], shape=(1,), dtype=float32)
# tf.Tensor([0.6994804], shape=(1,), dtype=float32)
# tf.Tensor([0.18238282], shape=(1,), dtype=float32)
# tf.Tensor([0.13988054], shape=(1,), dtype=float32)
# tf.Tensor([0.22714972], shape=(1,), dtype=float32)
# tf.Tensor([0.23423731], shape=(1,), dtype=float32)
# tf.Tensor([0.97840655], shape=(1,), dtype=float32)
# tf.Tensor([0.407457], shape=(1,), dtype=float32)
# tf.Tensor([0.15735805], shape=(1,), dtype=float32)
# tf.Tensor([0.04685068], shape=(1,), dtype=float32)
# tf.Tensor([0.9774703], shape=(1,), dtype=float32)
# tf.Tensor([0.73826194], shape=(1,), dtype=float32)
# tf.Tensor([0.3575846], shape=(1,), dtype=float32)
# tf.Tensor([0.71170115], shape=(1,), dtype=float32)
# tf.Tensor([0.07405865], shape=(1,), dtype=float32)
# tf.Tensor([0.7978742], shape=(1,), dtype=float32)
# tf.Tensor([0.25773048], shape=(1,), dtype=float32)
# tf.Tensor([0.03192949], shape=(1,), dtype=float32)
# tf.Tensor([0.60863626], shape=(1,), dtype=float32)
# tf.Tensor([0.15605521], shape=(1,), dtype=float32)
# tf.Tensor([0.03979504], shape=(1,), dtype=float32)
# tf.Tensor([0.84713554], shape=(1,), dtype=float32)
# tf.Tensor([0.480011], shape=(1,), dtype=float32)
# tf.Tensor([0.54442406], shape=(1,), dtype=float32)
# tf.Tensor([0.99601555], shape=(1,), dtype=float32)
# tf.Tensor([0.23037803], shape=(1,), dtype=float32)
# tf.Tensor([0.7010287], shape=(1,), dtype=float32)
# tf.Tensor([0.5073575], shape=(1,), dtype=float32)
# tf.Tensor([0.2206111], shape=(1,), dtype=float32)
# tf.Tensor([0.7326232], shape=(1,), dtype=float32)
# tf.Tensor([0.11413717], shape=(1,), dtype=float32)
# tf.Tensor([0.553434], shape=(1,), dtype=float32)
# tf.Tensor([0.02898562], shape=(1,), dtype=float32)
# tf.Tensor([0.06493938], shape=(1,), dtype=float32)
# tf.Tensor([0.72072554], shape=(1,), dtype=float32)
# tf.Tensor([0.7953603], shape=(1,), dtype=float32)
# tf.Tensor([0.40659654], shape=(1,), dtype=float32)
# tf.Tensor([0.9540591], shape=(1,), dtype=float32)
# tf.Tensor([0.52440095], shape=(1,), dtype=float32)
# tf.Tensor([0.04973388], shape=(1,), dtype=float32)
# tf.Tensor([0.78298104], shape=(1,), dtype=float32)
# tf.Tensor([0.42775643], shape=(1,), dtype=float32)
# tf.Tensor([0.9311409], shape=(1,), dtype=float32)
# tf.Tensor([0.75240874], shape=(1,), dtype=float32)
# tf.Tensor([0.25064588], shape=(1,), dtype=float32)
# tf.Tensor([0.87831473], shape=(1,), dtype=float32)
# tf.Tensor([0.03354704], shape=(1,), dtype=float32)
# tf.Tensor([0.1431117], shape=(1,), dtype=float32)
# tf.Tensor([0.09609973], shape=(1,), dtype=float32)
# tf.Tensor([0.01339519], shape=(1,), dtype=float32)
# tf.Tensor([0.95261216], shape=(1,), dtype=float32)
# tf.Tensor([0.8528236], shape=(1,), dtype=float32)
# tf.Tensor([0.51685476], shape=(1,), dtype=float32)
# tf.Tensor([0.1928643], shape=(1,), dtype=float32)
# tf.Tensor([0.4725399], shape=(1,), dtype=float32)
# tf.Tensor([0.11591327], shape=(1,), dtype=float32)
# tf.Tensor([0.08053362], shape=(1,), dtype=float32)
# tf.Tensor([0.81552577], shape=(1,), dtype=float32)
# tf.Tensor([0.9031377], shape=(1,), dtype=float32)
# tf.Tensor([0.83166826], shape=(1,), dtype=float32)
# tf.Tensor([0.9680573], shape=(1,), dtype=float32)
# tf.Tensor([0.66406894], shape=(1,), dtype=float32)
# tf.Tensor([0.08815837], shape=(1,), dtype=float32)
# tf.Tensor([0.52224195], shape=(1,), dtype=float32)
# tf.Tensor([0.2634685], shape=(1,), dtype=float32)
# tf.Tensor([0.28872597], shape=(1,), dtype=float32)
# tf.Tensor([0.18515861], shape=(1,), dtype=float32)
# tf.Tensor([0.8545501], shape=(1,), dtype=float32)
# tf.Tensor([0.57512534], shape=(1,), dtype=float32)
# tf.Tensor([0.6536311], shape=(1,), dtype=float32)
# tf.Tensor([0.913942], shape=(1,), dtype=float32)
# tf.Tensor([0.4456879], shape=(1,), dtype=float32)
# tf.Tensor([0.34042215], shape=(1,), dtype=float32)
# tf.Tensor([0.5177282], shape=(1,), dtype=float32)
# tf.Tensor([0.15119767], shape=(1,), dtype=float32)
# tf.Tensor([0.98563504], shape=(1,), dtype=float32)
# tf.Tensor([0.06809986], shape=(1,), dtype=float32)
# tf.Tensor([0.6728209], shape=(1,), dtype=float32)
# tf.Tensor([0.07218766], shape=(1,), dtype=float32)
# tf.Tensor([0.8723613], shape=(1,), dtype=float32)
# tf.Tensor([0.529904], shape=(1,), dtype=float32)
# tf.Tensor([0.5444274], shape=(1,), dtype=float32)
# tf.Tensor([0.45584357], shape=(1,), dtype=float32)
# tf.Tensor([0.40225613], shape=(1,), dtype=float32)
# tf.Tensor([0.80232215], shape=(1,), dtype=float32)
# tf.Tensor([0.22366834], shape=(1,), dtype=float32)
# tf.Tensor([0.2701248], shape=(1,), dtype=float32)
# tf.Tensor([0.5635631], shape=(1,), dtype=float32)
# tf.Tensor([0.16025543], shape=(1,), dtype=float32)
# tf.Tensor([0.29545057], shape=(1,), dtype=float32)
# tf.Tensor([0.31054306], shape=(1,), dtype=float32)
# tf.Tensor([0.04179454], shape=(1,), dtype=float32)
# tf.Tensor([0.5002575], shape=(1,), dtype=float32)
# tf.Tensor([0.4715129], shape=(1,), dtype=float32)
# tf.Tensor([0.5707785], shape=(1,), dtype=float32)
# tf.Tensor([0.21001458], shape=(1,), dtype=float32)
# tf.Tensor([0.67229915], shape=(1,), dtype=float32)
# tf.Tensor([0.09922445], shape=(1,), dtype=float32)
# tf.Tensor([0.04526031], shape=(1,), dtype=float32)
# tf.Tensor([0.14175403], shape=(1,), dtype=float32)
# tf.Tensor([0.83989644], shape=(1,), dtype=float32)
# tf.Tensor([0.57596827], shape=(1,), dtype=float32)
# tf.Tensor([0.09056199], shape=(1,), dtype=float32)
# tf.Tensor([0.3550086], shape=(1,), dtype=float32)
# tf.Tensor([0.7352469], shape=(1,), dtype=float32)
# tf.Tensor([0.23686576], shape=(1,), dtype=float32)
# tf.Tensor([0.18335688], shape=(1,), dtype=float32)
# tf.Tensor([0.6157942], shape=(1,), dtype=float32)
# tf.Tensor([0.64408636], shape=(1,), dtype=float32)
# tf.Tensor([0.45336926], shape=(1,), dtype=float32)
# tf.Tensor([0.26254296], shape=(1,), dtype=float32)
# tf.Tensor([0.9056655], shape=(1,), dtype=float32)
# tf.Tensor([0.02172911], shape=(1,), dtype=float32)
# tf.Tensor([0.33988118], shape=(1,), dtype=float32)
# tf.Tensor([0.07041585], shape=(1,), dtype=float32)
# tf.Tensor([0.9406537], shape=(1,), dtype=float32)
# tf.Tensor([0.5734681], shape=(1,), dtype=float32)
# tf.Tensor([0.7015178], shape=(1,), dtype=float32)
# tf.Tensor([0.14647818], shape=(1,), dtype=float32)
# tf.Tensor([0.37064922], shape=(1,), dtype=float32)
# tf.Tensor([0.59642196], shape=(1,), dtype=float32)
# tf.Tensor([0.19835007], shape=(1,), dtype=float32)
# tf.Tensor([0.65848243], shape=(1,), dtype=float32)
# tf.Tensor([0.48270428], shape=(1,), dtype=float32)
# tf.Tensor([0.5928205], shape=(1,), dtype=float32)
# tf.Tensor([0.81330884], shape=(1,), dtype=float32)
# tf.Tensor([0.1468302], shape=(1,), dtype=float32)
# tf.Tensor([0.7055532], shape=(1,), dtype=float32)
# tf.Tensor([0.43445826], shape=(1,), dtype=float32)
# tf.Tensor([0.05986786], shape=(1,), dtype=float32)
# tf.Tensor([0.97973275], shape=(1,), dtype=float32)
# tf.Tensor([0.8230891], shape=(1,), dtype=float32)
# tf.Tensor([0.70798147], shape=(1,), dtype=float32)
# tf.Tensor([0.96832025], shape=(1,), dtype=float32)
# tf.Tensor([0.09668887], shape=(1,), dtype=float32)
# tf.Tensor([0.93960917], shape=(1,), dtype=float32)
# tf.Tensor([0.43327367], shape=(1,), dtype=float32)
# tf.Tensor([0.28732586], shape=(1,), dtype=float32)
# tf.Tensor([0.7666209], shape=(1,), dtype=float32)
# tf.Tensor([0.17878473], shape=(1,), dtype=float32)
# tf.Tensor([0.39428198], shape=(1,), dtype=float32)
# tf.Tensor([0.20306301], shape=(1,), dtype=float32)
# tf.Tensor([0.743991], shape=(1,), dtype=float32)
# tf.Tensor([0.8931365], shape=(1,), dtype=float32)
# tf.Tensor([0.31538844], shape=(1,), dtype=float32)
# tf.Tensor([0.7537539], shape=(1,), dtype=float32)
# tf.Tensor([0.07457173], shape=(1,), dtype=float32)
# tf.Tensor([0.78755546], shape=(1,), dtype=float32)
# tf.Tensor([0.9734951], shape=(1,), dtype=float32)
# tf.Tensor([0.47425902], shape=(1,), dtype=float32)
# tf.Tensor([0.04069483], shape=(1,), dtype=float32)
# tf.Tensor([0.9165671], shape=(1,), dtype=float32)
# tf.Tensor([0.15350771], shape=(1,), dtype=float32)
# tf.Tensor([0.81981075], shape=(1,), dtype=float32)
# tf.Tensor([0.77165127], shape=(1,), dtype=float32)
# tf.Tensor([0.16479921], shape=(1,), dtype=float32)
# tf.Tensor([0.18317854], shape=(1,), dtype=float32)
# tf.Tensor([0.08647907], shape=(1,), dtype=float32)
# tf.Tensor([0.3682233], shape=(1,), dtype=float32)
# tf.Tensor([0.8039267], shape=(1,), dtype=float32)
# tf.Tensor([0.59842885], shape=(1,), dtype=float32)
# tf.Tensor([0.80349827], shape=(1,), dtype=float32)
# tf.Tensor([0.70660627], shape=(1,), dtype=float32)
# tf.Tensor([0.72924304], shape=(1,), dtype=float32)
# tf.Tensor([0.3743794], shape=(1,), dtype=float32)
# tf.Tensor([0.11647081], shape=(1,), dtype=float32)
# tf.Tensor([0.96474624], shape=(1,), dtype=float32)
# tf.Tensor([0.85754573], shape=(1,), dtype=float32)
# tf.Tensor([0.6994426], shape=(1,), dtype=float32)
# tf.Tensor([0.87167], shape=(1,), dtype=float32)
# tf.Tensor([0.8990711], shape=(1,), dtype=float32)
# tf.Tensor([0.68822765], shape=(1,), dtype=float32)
# tf.Tensor([0.22468102], shape=(1,), dtype=float32)
# tf.Tensor([0.759349], shape=(1,), dtype=float32)
# tf.Tensor([0.33283246], shape=(1,), dtype=float32)
# tf.Tensor([0.8840425], shape=(1,), dtype=float32)
# tf.Tensor([0.45063603], shape=(1,), dtype=float32)
# tf.Tensor([0.07388341], shape=(1,), dtype=float32)
# tf.Tensor([0.91700757], shape=(1,), dtype=float32)
# tf.Tensor([0.3264172], shape=(1,), dtype=float32)
# tf.Tensor([0.85431874], shape=(1,), dtype=float32)
# tf.Tensor([0.55014336], shape=(1,), dtype=float32)
# tf.Tensor([0.46176696], shape=(1,), dtype=float32)
# tf.Tensor([0.44034934], shape=(1,), dtype=float32)
# tf.Tensor([0.24438], shape=(1,), dtype=float32)
# tf.Tensor([0.7369356], shape=(1,), dtype=float32)
# tf.Tensor([0.8771527], shape=(1,), dtype=float32)
# tf.Tensor([0.76802254], shape=(1,), dtype=float32)
# tf.Tensor([0.7779008], shape=(1,), dtype=float32)
# tf.Tensor([0.38463473], shape=(1,), dtype=float32)
# tf.Tensor([0.09147429], shape=(1,), dtype=float32)
# tf.Tensor([0.39575386], shape=(1,), dtype=float32)
# tf.Tensor([0.6021906], shape=(1,), dtype=float32)
# tf.Tensor([0.10827839], shape=(1,), dtype=float32)
# tf.Tensor([0.0300076], shape=(1,), dtype=float32)
# tf.Tensor([0.40040123], shape=(1,), dtype=float32)
# tf.Tensor([0.5106957], shape=(1,), dtype=float32)
# tf.Tensor([0.8391179], shape=(1,), dtype=float32)
# tf.Tensor([0.37744164], shape=(1,), dtype=float32)
# tf.Tensor([0.96319723], shape=(1,), dtype=float32)
# tf.Tensor([0.35828304], shape=(1,), dtype=float32)
# tf.Tensor([0.74572635], shape=(1,), dtype=float32)
# tf.Tensor([0.5283216], shape=(1,), dtype=float32)
# tf.Tensor([0.96046245], shape=(1,), dtype=float32)
# tf.Tensor([0.7954869], shape=(1,), dtype=float32)
# tf.Tensor([0.4683901], shape=(1,), dtype=float32)
# tf.Tensor([0.52830005], shape=(1,), dtype=float32)
# tf.Tensor([0.46300673], shape=(1,), dtype=float32)
# tf.Tensor([0.00921154], shape=(1,), dtype=float32)
# tf.Tensor([0.06204712], shape=(1,), dtype=float32)
# tf.Tensor([0.24127054], shape=(1,), dtype=float32)
# tf.Tensor([0.05455267], shape=(1,), dtype=float32)
# tf.Tensor([0.45052648], shape=(1,), dtype=float32)
# tf.Tensor([0.3951584], shape=(1,), dtype=float32)
# tf.Tensor([0.02704227], shape=(1,), dtype=float32)
# tf.Tensor([0.04185104], shape=(1,), dtype=float32)
# tf.Tensor([0.5071374], shape=(1,), dtype=float32)
# tf.Tensor([0.515635], shape=(1,), dtype=float32)
# tf.Tensor([0.21155679], shape=(1,), dtype=float32)
# tf.Tensor([0.9008975], shape=(1,), dtype=float32)
# tf.Tensor([0.14033353], shape=(1,), dtype=float32)
# tf.Tensor([0.06566226], shape=(1,), dtype=float32)
# tf.Tensor([0.17428958], shape=(1,), dtype=float32)
# tf.Tensor([0.819394], shape=(1,), dtype=float32)
# tf.Tensor([0.56600785], shape=(1,), dtype=float32)
# tf.Tensor([0.7238885], shape=(1,), dtype=float32)
# tf.Tensor([0.7290355], shape=(1,), dtype=float32)
# tf.Tensor([0.20176208], shape=(1,), dtype=float32)
# tf.Tensor([0.36253655], shape=(1,), dtype=float32)
# tf.Tensor([0.08852327], shape=(1,), dtype=float32)
# tf.Tensor([0.6950815], shape=(1,), dtype=float32)
# tf.Tensor([0.59155667], shape=(1,), dtype=float32)
# tf.Tensor([0.71113384], shape=(1,), dtype=float32)
# tf.Tensor([0.36808324], shape=(1,), dtype=float32)
# tf.Tensor([0.22000515], shape=(1,), dtype=float32)
# tf.Tensor([0.39775229], shape=(1,), dtype=float32)
# tf.Tensor([0.72036755], shape=(1,), dtype=float32)
# tf.Tensor([0.26099145], shape=(1,), dtype=float32)
# tf.Tensor([0.2713505], shape=(1,), dtype=float32)
# tf.Tensor([0.8589121], shape=(1,), dtype=float32)
# tf.Tensor([0.35333598], shape=(1,), dtype=float32)
# tf.Tensor([0.7637702], shape=(1,), dtype=float32)
# tf.Tensor([0.477713], shape=(1,), dtype=float32)
# tf.Tensor([0.02399755], shape=(1,), dtype=float32)
# tf.Tensor([0.28371012], shape=(1,), dtype=float32)
# tf.Tensor([0.97250426], shape=(1,), dtype=float32)
# tf.Tensor([0.29590094], shape=(1,), dtype=float32)
# tf.Tensor([0.48439634], shape=(1,), dtype=float32)
# tf.Tensor([0.6805005], shape=(1,), dtype=float32)
# tf.Tensor([0.24390829], shape=(1,), dtype=float32)
# tf.Tensor([0.9425745], shape=(1,), dtype=float32)
# tf.Tensor([0.07716703], shape=(1,), dtype=float32)
# tf.Tensor([0.21264744], shape=(1,), dtype=float32)
# tf.Tensor([0.0313189], shape=(1,), dtype=float32)
# tf.Tensor([0.5923964], shape=(1,), dtype=float32)
# tf.Tensor([0.81559324], shape=(1,), dtype=float32)
# tf.Tensor([0.9431777], shape=(1,), dtype=float32)
# tf.Tensor([0.08417082], shape=(1,), dtype=float32)
# tf.Tensor([0.5288689], shape=(1,), dtype=float32)
# tf.Tensor([0.93007886], shape=(1,), dtype=float32)
# tf.Tensor([0.07224298], shape=(1,), dtype=float32)
# tf.Tensor([0.17654026], shape=(1,), dtype=float32)
# tf.Tensor([0.7033237], shape=(1,), dtype=float32)
# tf.Tensor([0.4390509], shape=(1,), dtype=float32)
# tf.Tensor([0.53360057], shape=(1,), dtype=float32)
# tf.Tensor([0.66743696], shape=(1,), dtype=float32)
# tf.Tensor([0.44860363], shape=(1,), dtype=float32)
# tf.Tensor([0.83586586], shape=(1,), dtype=float32)
# tf.Tensor([0.7207047], shape=(1,), dtype=float32)
# tf.Tensor([0.52224755], shape=(1,), dtype=float32)
# tf.Tensor([0.7801198], shape=(1,), dtype=float32)
# tf.Tensor([0.16525865], shape=(1,), dtype=float32)
# tf.Tensor([0.35160506], shape=(1,), dtype=float32)
# tf.Tensor([0.74400806], shape=(1,), dtype=float32)
# tf.Tensor([0.28333783], shape=(1,), dtype=float32)
# tf.Tensor([0.96151197], shape=(1,), dtype=float32)
# tf.Tensor([0.9574983], shape=(1,), dtype=float32)
# tf.Tensor([0.603281], shape=(1,), dtype=float32)
# tf.Tensor([0.62056077], shape=(1,), dtype=float32)
# tf.Tensor([0.12913322], shape=(1,), dtype=float32)
# tf.Tensor([0.82561123], shape=(1,), dtype=float32)
# tf.Tensor([0.03180373], shape=(1,), dtype=float32)
# tf.Tensor([0.44621885], shape=(1,), dtype=float32)
# tf.Tensor([0.17768526], shape=(1,), dtype=float32)
# tf.Tensor([0.4313656], shape=(1,), dtype=float32)
# tf.Tensor([0.61149275], shape=(1,), dtype=float32)
# tf.Tensor([0.46895158], shape=(1,), dtype=float32)
# tf.Tensor([0.38723946], shape=(1,), dtype=float32)
# tf.Tensor([0.44397676], shape=(1,), dtype=float32)
# tf.Tensor([0.13361716], shape=(1,), dtype=float32)
# tf.Tensor([0.07410789], shape=(1,), dtype=float32)
# tf.Tensor([0.5354985], shape=(1,), dtype=float32)
# tf.Tensor([0.7974982], shape=(1,), dtype=float32)
# tf.Tensor([0.99079907], shape=(1,), dtype=float32)
# tf.Tensor([0.15688694], shape=(1,), dtype=float32)
# tf.Tensor([0.9780662], shape=(1,), dtype=float32)
# tf.Tensor([0.6502497], shape=(1,), dtype=float32)
# tf.Tensor([0.6120881], shape=(1,), dtype=float32)
# tf.Tensor([0.6948662], shape=(1,), dtype=float32)
# tf.Tensor([0.43976545], shape=(1,), dtype=float32)
# tf.Tensor([0.6305325], shape=(1,), dtype=float32)
# tf.Tensor([0.42721474], shape=(1,), dtype=float32)
# tf.Tensor([0.21142387], shape=(1,), dtype=float32)
# tf.Tensor([0.45682728], shape=(1,), dtype=float32)
# tf.Tensor([0.5300777], shape=(1,), dtype=float32)
# tf.Tensor([0.13097548], shape=(1,), dtype=float32)
# tf.Tensor([0.4927472], shape=(1,), dtype=float32)
# tf.Tensor([0.53259265], shape=(1,), dtype=float32)
# tf.Tensor([0.7169516], shape=(1,), dtype=float32)
# tf.Tensor([0.76956534], shape=(1,), dtype=float32)
# tf.Tensor([0.8790319], shape=(1,), dtype=float32)
# tf.Tensor([0.26213467], shape=(1,), dtype=float32)
# tf.Tensor([0.36850476], shape=(1,), dtype=float32)
# tf.Tensor([0.5735444], shape=(1,), dtype=float32)
# tf.Tensor([0.04854703], shape=(1,), dtype=float32)
# tf.Tensor([0.6964772], shape=(1,), dtype=float32)
# tf.Tensor([0.7246592], shape=(1,), dtype=float32)
# tf.Tensor([0.54586625], shape=(1,), dtype=float32)
# tf.Tensor([0.6798762], shape=(1,), dtype=float32)
# tf.Tensor([0.32263112], shape=(1,), dtype=float32)
# tf.Tensor([0.05250967], shape=(1,), dtype=float32)
# tf.Tensor([0.42827046], shape=(1,), dtype=float32)
# tf.Tensor([0.93382704], shape=(1,), dtype=float32)
# tf.Tensor([0.6565385], shape=(1,), dtype=float32)
# tf.Tensor([0.45701778], shape=(1,), dtype=float32)
# tf.Tensor([0.27427053], shape=(1,), dtype=float32)
# tf.Tensor([0.08915341], shape=(1,), dtype=float32)
# tf.Tensor([0.3620752], shape=(1,), dtype=float32)
# tf.Tensor([0.17943239], shape=(1,), dtype=float32)
# tf.Tensor([0.35299742], shape=(1,), dtype=float32)
# tf.Tensor([0.93355525], shape=(1,), dtype=float32)
# tf.Tensor([0.6730677], shape=(1,), dtype=float32)
# tf.Tensor([0.98149514], shape=(1,), dtype=float32)
# tf.Tensor([0.07549489], shape=(1,), dtype=float32)
# tf.Tensor([0.82836795], shape=(1,), dtype=float32)
# tf.Tensor([0.69118285], shape=(1,), dtype=float32)
# tf.Tensor([0.68085206], shape=(1,), dtype=float32)
# tf.Tensor([0.52224314], shape=(1,), dtype=float32)
# tf.Tensor([0.719677], shape=(1,), dtype=float32)
# tf.Tensor([0.9155233], shape=(1,), dtype=float32)
# tf.Tensor([0.732545], shape=(1,), dtype=float32)
# tf.Tensor([0.14815402], shape=(1,), dtype=float32)
# tf.Tensor([0.0807327], shape=(1,), dtype=float32)
# tf.Tensor([0.12065732], shape=(1,), dtype=float32)
# tf.Tensor([0.7762561], shape=(1,), dtype=float32)
# tf.Tensor([0.72443974], shape=(1,), dtype=float32)
# tf.Tensor([0.21361566], shape=(1,), dtype=float32)
# tf.Tensor([0.11537445], shape=(1,), dtype=float32)
# tf.Tensor([0.5359181], shape=(1,), dtype=float32)
# tf.Tensor([0.82052386], shape=(1,), dtype=float32)
# tf.Tensor([0.31798708], shape=(1,), dtype=float32)
# tf.Tensor([0.04708147], shape=(1,), dtype=float32)
# tf.Tensor([0.77424467], shape=(1,), dtype=float32)
# tf.Tensor([0.35691547], shape=(1,), dtype=float32)
# tf.Tensor([0.8347769], shape=(1,), dtype=float32)
# tf.Tensor([0.54714346], shape=(1,), dtype=float32)
# tf.Tensor([0.7820325], shape=(1,), dtype=float32)
# tf.Tensor([0.26824796], shape=(1,), dtype=float32)
# tf.Tensor([0.42178667], shape=(1,), dtype=float32)
# tf.Tensor([0.7633995], shape=(1,), dtype=float32)
# tf.Tensor([0.4740758], shape=(1,), dtype=float32)
# tf.Tensor([0.7717452], shape=(1,), dtype=float32)
# tf.Tensor([0.02491975], shape=(1,), dtype=float32)
# tf.Tensor([0.83433855], shape=(1,), dtype=float32)
# tf.Tensor([0.7960448], shape=(1,), dtype=float32)
# tf.Tensor([0.73769116], shape=(1,), dtype=float32)
# tf.Tensor([0.12856638], shape=(1,), dtype=float32)
# tf.Tensor([0.31079245], shape=(1,), dtype=float32)
# tf.Tensor([0.79988873], shape=(1,), dtype=float32)
# tf.Tensor([0.6157993], shape=(1,), dtype=float32)
# tf.Tensor([0.4159181], shape=(1,), dtype=float32)
# tf.Tensor([0.11695504], shape=(1,), dtype=float32)
# tf.Tensor([0.9083928], shape=(1,), dtype=float32)
# tf.Tensor([0.5466062], shape=(1,), dtype=float32)
# tf.Tensor([0.00595129], shape=(1,), dtype=float32)
# tf.Tensor([0.43722332], shape=(1,), dtype=float32)
# tf.Tensor([0.62362456], shape=(1,), dtype=float32)
# tf.Tensor([0.03906834], shape=(1,), dtype=float32)
# tf.Tensor([0.35226595], shape=(1,), dtype=float32)
# tf.Tensor([0.57742035], shape=(1,), dtype=float32)
# tf.Tensor([0.12731111], shape=(1,), dtype=float32)
# tf.Tensor([0.9126266], shape=(1,), dtype=float32)
# tf.Tensor([0.53318965], shape=(1,), dtype=float32)
# tf.Tensor([0.995801], shape=(1,), dtype=float32)
# tf.Tensor([0.695997], shape=(1,), dtype=float32)
# tf.Tensor([0.8449094], shape=(1,), dtype=float32)
# tf.Tensor([0.6800593], shape=(1,), dtype=float32)
# tf.Tensor([0.16597998], shape=(1,), dtype=float32)
# tf.Tensor([0.8277246], shape=(1,), dtype=float32)
# tf.Tensor([0.578506], shape=(1,), dtype=float32)
# tf.Tensor([0.6174749], shape=(1,), dtype=float32)
# tf.Tensor([0.6144799], shape=(1,), dtype=float32)
# tf.Tensor([0.09222317], shape=(1,), dtype=float32)
# tf.Tensor([0.6185851], shape=(1,), dtype=float32)
# tf.Tensor([0.4951297], shape=(1,), dtype=float32)
# tf.Tensor([0.23025882], shape=(1,), dtype=float32)
# tf.Tensor([0.2412914], shape=(1,), dtype=float32)
# tf.Tensor([0.35220373], shape=(1,), dtype=float32)
# tf.Tensor([0.35594654], shape=(1,), dtype=float32)
# tf.Tensor([0.8717109], shape=(1,), dtype=float32)
# tf.Tensor([0.3802073], shape=(1,), dtype=float32)
# tf.Tensor([0.05580521], shape=(1,), dtype=float32)
# tf.Tensor([0.5721595], shape=(1,), dtype=float32)
# tf.Tensor([0.29954672], shape=(1,), dtype=float32)
# tf.Tensor([0.29712915], shape=(1,), dtype=float32)
# tf.Tensor([0.4348085], shape=(1,), dtype=float32)
# tf.Tensor([0.49582827], shape=(1,), dtype=float32)
# tf.Tensor([0.76887953], shape=(1,), dtype=float32)
# tf.Tensor([0.02376461], shape=(1,), dtype=float32)
# tf.Tensor([0.15840149], shape=(1,), dtype=float32)
# tf.Tensor([0.6880902], shape=(1,), dtype=float32)
# tf.Tensor([0.49889672], shape=(1,), dtype=float32)
# tf.Tensor([0.92900705], shape=(1,), dtype=float32)
# tf.Tensor([0.8904817], shape=(1,), dtype=float32)
# tf.Tensor([0.91489244], shape=(1,), dtype=float32)
# tf.Tensor([0.6742984], shape=(1,), dtype=float32)
# tf.Tensor([0.29124367], shape=(1,), dtype=float32)
# tf.Tensor([0.9189329], shape=(1,), dtype=float32)
# tf.Tensor([0.9042697], shape=(1,), dtype=float32)
# tf.Tensor([0.32527244], shape=(1,), dtype=float32)
# tf.Tensor([0.9600562], shape=(1,), dtype=float32)
# tf.Tensor([0.9462373], shape=(1,), dtype=float32)
# tf.Tensor([0.25536585], shape=(1,), dtype=float32)
# tf.Tensor([0.431149], shape=(1,), dtype=float32)
# tf.Tensor([0.19128609], shape=(1,), dtype=float32)
# tf.Tensor([0.06069553], shape=(1,), dtype=float32)
# tf.Tensor([0.3485285], shape=(1,), dtype=float32)
# tf.Tensor([0.3631767], shape=(1,), dtype=float32)
# tf.Tensor([0.28454435], shape=(1,), dtype=float32)
# tf.Tensor([0.16622019], shape=(1,), dtype=float32)
# tf.Tensor([0.3214507], shape=(1,), dtype=float32)
# tf.Tensor([0.5329633], shape=(1,), dtype=float32)
# tf.Tensor([0.55136037], shape=(1,), dtype=float32)
# tf.Tensor([0.76271164], shape=(1,), dtype=float32)
# tf.Tensor([0.43861282], shape=(1,), dtype=float32)
# tf.Tensor([0.43439722], shape=(1,), dtype=float32)
# tf.Tensor([0.6278498], shape=(1,), dtype=float32)
# tf.Tensor([0.9037286], shape=(1,), dtype=float32)
# tf.Tensor([0.43417656], shape=(1,), dtype=float32)
# tf.Tensor([0.43874002], shape=(1,), dtype=float32)
# tf.Tensor([0.23501492], shape=(1,), dtype=float32)
# tf.Tensor([0.7174102], shape=(1,), dtype=float32)
# tf.Tensor([0.01783311], shape=(1,), dtype=float32)
# tf.Tensor([0.717819], shape=(1,), dtype=float32)
# tf.Tensor([0.8025985], shape=(1,), dtype=float32)
# tf.Tensor([0.35081375], shape=(1,), dtype=float32)
# tf.Tensor([0.6941855], shape=(1,), dtype=float32)
# tf.Tensor([0.89421713], shape=(1,), dtype=float32)
# tf.Tensor([0.7117598], shape=(1,), dtype=float32)
# tf.Tensor([0.77733994], shape=(1,), dtype=float32)
# tf.Tensor([0.31864476], shape=(1,), dtype=float32)
# tf.Tensor([0.3509599], shape=(1,), dtype=float32)
# tf.Tensor([0.5260198], shape=(1,), dtype=float32)
# tf.Tensor([0.02899468], shape=(1,), dtype=float32)
# tf.Tensor([0.93985784], shape=(1,), dtype=float32)
# tf.Tensor([0.12548637], shape=(1,), dtype=float32)
# tf.Tensor([0.43148053], shape=(1,), dtype=float32)
# tf.Tensor([0.07545471], shape=(1,), dtype=float32)
# tf.Tensor([0.28271317], shape=(1,), dtype=float32)
# tf.Tensor([0.15985084], shape=(1,), dtype=float32)
# tf.Tensor([0.31627965], shape=(1,), dtype=float32)
# tf.Tensor([0.761075], shape=(1,), dtype=float32)
# tf.Tensor([0.63882875], shape=(1,), dtype=float32)
# tf.Tensor([0.25439906], shape=(1,), dtype=float32)
# tf.Tensor([0.10241175], shape=(1,), dtype=float32)
# tf.Tensor([0.2798282], shape=(1,), dtype=float32)
# tf.Tensor([0.00482595], shape=(1,), dtype=float32)
# tf.Tensor([0.5213225], shape=(1,), dtype=float32)
# tf.Tensor([0.8000388], shape=(1,), dtype=float32)
# tf.Tensor([0.88987076], shape=(1,), dtype=float32)
# tf.Tensor([0.9118384], shape=(1,), dtype=float32)
# tf.Tensor([0.03089643], shape=(1,), dtype=float32)
# tf.Tensor([0.30036438], shape=(1,), dtype=float32)
# tf.Tensor([0.5083536], shape=(1,), dtype=float32)
# tf.Tensor([0.1047107], shape=(1,), dtype=float32)
# tf.Tensor([0.81868184], shape=(1,), dtype=float32)
# tf.Tensor([0.61642694], shape=(1,), dtype=float32)
# tf.Tensor([0.53642106], shape=(1,), dtype=float32)
# tf.Tensor([0.22455525], shape=(1,), dtype=float32)
# tf.Tensor([0.76197433], shape=(1,), dtype=float32)
# tf.Tensor([0.55449843], shape=(1,), dtype=float32)
# tf.Tensor([0.29995573], shape=(1,), dtype=float32)
# tf.Tensor([0.276523], shape=(1,), dtype=float32)
# tf.Tensor([0.7354492], shape=(1,), dtype=float32)
# tf.Tensor([0.42821836], shape=(1,), dtype=float32)
# tf.Tensor([0.9366585], shape=(1,), dtype=float32)
# tf.Tensor([0.17660475], shape=(1,), dtype=float32)
# tf.Tensor([0.16066766], shape=(1,), dtype=float32)
# tf.Tensor([0.7188411], shape=(1,), dtype=float32)
# tf.Tensor([0.4341433], shape=(1,), dtype=float32)
# tf.Tensor([0.27724516], shape=(1,), dtype=float32)
# tf.Tensor([0.9762006], shape=(1,), dtype=float32)
# tf.Tensor([0.45590615], shape=(1,), dtype=float32)
# tf.Tensor([0.7837111], shape=(1,), dtype=float32)
# tf.Tensor([0.5745902], shape=(1,), dtype=float32)
# tf.Tensor([0.35671556], shape=(1,), dtype=float32)
# tf.Tensor([0.3987323], shape=(1,), dtype=float32)
# tf.Tensor([0.89984035], shape=(1,), dtype=float32)
# tf.Tensor([0.63931346], shape=(1,), dtype=float32)
# tf.Tensor([0.57114613], shape=(1,), dtype=float32)
# tf.Tensor([0.69623196], shape=(1,), dtype=float32)
# tf.Tensor([0.2796142], shape=(1,), dtype=float32)
# tf.Tensor([0.23365104], shape=(1,), dtype=float32)
# tf.Tensor([0.87445295], shape=(1,), dtype=float32)
# tf.Tensor([0.9322214], shape=(1,), dtype=float32)
# tf.Tensor([0.8611696], shape=(1,), dtype=float32)
# tf.Tensor([0.4134053], shape=(1,), dtype=float32)
# tf.Tensor([0.19887578], shape=(1,), dtype=float32)
# tf.Tensor([0.7210126], shape=(1,), dtype=float32)
# tf.Tensor([0.13438547], shape=(1,), dtype=float32)

# %%
# TF data approach (with batching)
generator_dataset = tf.data.Dataset.from_generator(my_generator, args=[1000], output_types=tf.float32, output_shapes=(1))
for data in generator_dataset.batch(10):
  print(data)
# Out:
# tf.Tensor(
# [[0.16083467]
#  [0.4409504 ]
#  [0.28390074]
#  [0.31091225]
#  [0.6245127 ]
#  [0.1452483 ]
#  [0.81280386]
#  [0.7549505 ]
#  [0.87484515]
#  [0.32321012]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.172256  ]
#  [0.52800465]
#  [0.16079545]
#  [0.17790401]
#  [0.64372504]
#  [0.6612303 ]
#  [0.351529  ]
#  [0.64212215]
#  [0.8795152 ]
#  [0.37303734]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.65413797]
#  [0.09908831]
#  [0.32144654]
#  [0.68531466]
#  [0.28770924]
#  [0.8808857 ]
#  [0.91681015]
#  [0.2883761 ]
#  [0.82795703]
#  [0.60646725]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.33460736]
#  [0.96000373]
#  [0.46340024]
#  [0.9240588 ]
#  [0.2875607 ]
#  [0.80893123]
#  [0.06501162]
#  [0.06923485]
#  [0.5056788 ]
#  [0.05903137]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.99903095]
#  [0.02457964]
#  [0.4107095 ]
#  [0.45208228]
#  [0.8538363 ]
#  [0.53129196]
#  [0.61314106]
#  [0.50105524]
#  [0.58193994]
#  [0.17133975]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.30836904]
#  [0.386837  ]
#  [0.51339734]
#  [0.5141263 ]
#  [0.14858496]
#  [0.39838493]
#  [0.6155671 ]
#  [0.3745072 ]
#  [0.26848054]
#  [0.07346356]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.19277644]
#  [0.9991056 ]
#  [0.72576225]
#  [0.79581785]
#  [0.42185378]
#  [0.98812985]
#  [0.7914159 ]
#  [0.32639635]
#  [0.6550745 ]
#  [0.8329582 ]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.17259955]
#  [0.41346073]
#  [0.07222807]
#  [0.20675254]
#  [0.7544439 ]
#  [0.33152044]
#  [0.9612992 ]
#  [0.0589124 ]
#  [0.0323236 ]
#  [0.32399464]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.5513743 ]
#  [0.01932776]
#  [0.93767715]
#  [0.67951214]
#  [0.37463748]
#  [0.14092326]
#  [0.8846154 ]
#  [0.7130885 ]
#  [0.5277928 ]
#  [0.9921886 ]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.61561024]
#  [0.79993916]
#  [0.9253119 ]
#  [0.71278584]
#  [0.6219579 ]
#  [0.05281448]
#  [0.31322908]
#  [0.7793437 ]
#  [0.14995337]
#  [0.6144285 ]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.1544596 ]
#  [0.4304912 ]
#  [0.41877985]
#  [0.3346746 ]
#  [0.00733376]
#  [0.5922296 ]
#  [0.06376243]
#  [0.9578103 ]
#  [0.52347267]
#  [0.6251912 ]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.14243937]
#  [0.7536138 ]
#  [0.12941968]
#  [0.05273533]
#  [0.50428843]
#  [0.6184033 ]
#  [0.03225636]
#  [0.6419344 ]
#  [0.8531221 ]
#  [0.7317376 ]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.60398185]
#  [0.4137709 ]
#  [0.08887017]
#  [0.41254616]
#  [0.22417486]
#  [0.7878045 ]
#  [0.8971952 ]
#  [0.229262  ]
#  [0.17537117]
#  [0.5875597 ]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.4594413 ]
#  [0.6992003 ]
#  [0.4205767 ]
#  [0.10331166]
#  [0.38545823]
#  [0.33143425]
#  [0.56825113]
#  [0.22154725]
#  [0.3906002 ]
#  [0.98738754]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.360978  ]
#  [0.59879947]
#  [0.35276628]
#  [0.1954062 ]
#  [0.01234853]
#  [0.8107686 ]
#  [0.8996537 ]
#  [0.5087341 ]
#  [0.08154047]
#  [0.7990211 ]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.6254846 ]
#  [0.07732332]
#  [0.4070499 ]
#  [0.7735654 ]
#  [0.30039895]
#  [0.14483964]
#  [0.6302204 ]
#  [0.56097996]
#  [0.54931796]
#  [0.8711227 ]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.6754669 ]
#  [0.4160862 ]
#  [0.43093884]
#  [0.82496893]
#  [0.94780254]
#  [0.6624905 ]
#  [0.04484797]
#  [0.3930534 ]
#  [0.3855772 ]
#  [0.77093124]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.4757886 ]
#  [0.04355752]
#  [0.4564401 ]
#  [0.3686887 ]
#  [0.2529751 ]
#  [0.34537995]
#  [0.47579098]
#  [0.3353511 ]
#  [0.44331086]
#  [0.9714949 ]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.14735353]
#  [0.51587486]
#  [0.70905995]
#  [0.00665212]
#  [0.25777233]
#  [0.7936423 ]
#  [0.07939088]
#  [0.7719002 ]
#  [0.03548622]
#  [0.49325776]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.9402199 ]
#  [0.08125186]
#  [0.41383886]
#  [0.5561421 ]
#  [0.8198477 ]
#  [0.7423408 ]
#  [0.40603638]
#  [0.93812454]
#  [0.29681885]
#  [0.8274044 ]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.3907286 ]
#  [0.4904176 ]
#  [0.09396577]
#  [0.7431493 ]
#  [0.38177884]
#  [0.8969662 ]
#  [0.84060776]
#  [0.65670633]
#  [0.5867245 ]
#  [0.62160885]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.74953604]
#  [0.59992456]
#  [0.01117206]
#  [0.8106109 ]
#  [0.17785466]
#  [0.29618192]
#  [0.1891663 ]
#  [0.24358773]
#  [0.5562991 ]
#  [0.4834776 ]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.19514632]
#  [0.69106114]
#  [0.35713542]
#  [0.14552796]
#  [0.91187286]
#  [0.01001048]
#  [0.65651643]
#  [0.54119205]
#  [0.44777918]
#  [0.56529915]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.5165113 ]
#  [0.70511186]
#  [0.5870632 ]
#  [0.89853394]
#  [0.6284882 ]
#  [0.9215863 ]
#  [0.05590999]
#  [0.44592512]
#  [0.72947454]
#  [0.40024102]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.2994907 ]
#  [0.5506742 ]
#  [0.36375856]
#  [0.30711687]
#  [0.86792254]
#  [0.6492038 ]
#  [0.79921675]
#  [0.5054791 ]
#  [0.36512327]
#  [0.22380066]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.9185045 ]
#  [0.88883436]
#  [0.83480954]
#  [0.88364446]
#  [0.44754875]
#  [0.57025504]
#  [0.12588704]
#  [0.05617833]
#  [0.31042743]
#  [0.08826268]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.24121964]
#  [0.51142526]
#  [0.8347243 ]
#  [0.47906864]
#  [0.18017411]
#  [0.58145845]
#  [0.06575251]
#  [0.11558247]
#  [0.48763943]
#  [0.47059703]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.64814436]
#  [0.29945683]
#  [0.6041031 ]
#  [0.67404246]
#  [0.325109  ]
#  [0.4789021 ]
#  [0.46565425]
#  [0.47761345]
#  [0.28607976]
#  [0.24103737]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.5303383 ]
#  [0.2615924 ]
#  [0.29880655]
#  [0.08343923]
#  [0.16957164]
#  [0.30130208]
#  [0.54500866]
#  [0.9059037 ]
#  [0.5153247 ]
#  [0.80460155]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.49526143]
#  [0.8161862 ]
#  [0.35961807]
#  [0.7759495 ]
#  [0.31505227]
#  [0.35491145]
#  [0.47552013]
#  [0.8476896 ]
#  [0.24216604]
#  [0.2566836 ]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.21395993]
#  [0.08601069]
#  [0.33047056]
#  [0.06353557]
#  [0.61404955]
#  [0.06698704]
#  [0.9043653 ]
#  [0.9601296 ]
#  [0.8290744 ]
#  [0.0124917 ]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.3192824 ]
#  [0.5699512 ]
#  [0.15754187]
#  [0.6434244 ]
#  [0.20663404]
#  [0.5923835 ]
#  [0.82421684]
#  [0.00619078]
#  [0.6449938 ]
#  [0.4742918 ]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.25473893]
#  [0.4267311 ]
#  [0.3088236 ]
#  [0.38495278]
#  [0.0772692 ]
#  [0.9021095 ]
#  [0.53719103]
#  [0.68818593]
#  [0.04128683]
#  [0.16955972]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.6779257 ]
#  [0.05195761]
#  [0.16435587]
#  [0.9766458 ]
#  [0.82564056]
#  [0.1806407 ]
#  [0.8551061 ]
#  [0.12337685]
#  [0.91094315]
#  [0.77980363]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.82177603]
#  [0.29033732]
#  [0.59995675]
#  [0.24216878]
#  [0.35692227]
#  [0.66505194]
#  [0.22830844]
#  [0.65332913]
#  [0.15362084]
#  [0.25651073]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.9977517 ]
#  [0.52526176]
#  [0.73997474]
#  [0.36248386]
#  [0.36230767]
#  [0.37618053]
#  [0.26750267]
#  [0.38539386]
#  [0.6869767 ]
#  [0.8321333 ]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.6550348 ]
#  [0.67967916]
#  [0.38475323]
#  [0.04271305]
#  [0.21157622]
#  [0.31818128]
#  [0.6068407 ]
#  [0.30507517]
#  [0.16958928]
#  [0.2047255 ]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.9335104 ]
#  [0.46477365]
#  [0.7996713 ]
#  [0.6359967 ]
#  [0.60861444]
#  [0.41554546]
#  [0.85208774]
#  [0.5085585 ]
#  [0.8922161 ]
#  [0.88623464]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.24524677]
#  [0.42274952]
#  [0.7335354 ]
#  [0.45490623]
#  [0.40084696]
#  [0.86403286]
#  [0.53360903]
#  [0.8921975 ]
#  [0.6689453 ]
#  [0.2200011 ]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.23915482]
#  [0.20273256]
#  [0.8836204 ]
#  [0.648487  ]
#  [0.8468877 ]
#  [0.44545555]
#  [0.83682466]
#  [0.7789011 ]
#  [0.5530888 ]
#  [0.5178125 ]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.9777441 ]
#  [0.15768564]
#  [0.4871254 ]
#  [0.39165294]
#  [0.10972035]
#  [0.3376304 ]
#  [0.49260533]
#  [0.8518188 ]
#  [0.5298383 ]
#  [0.6116152 ]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.35055256]
#  [0.16392756]
#  [0.28428698]
#  [0.10503268]
#  [0.59272075]
#  [0.7247963 ]
#  [0.39384413]
#  [0.5444834 ]
#  [0.7238134 ]
#  [0.6730114 ]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.87547565]
#  [0.90151095]
#  [0.16564095]
#  [0.24264967]
#  [0.7500311 ]
#  [0.976575  ]
#  [0.8856076 ]
#  [0.1934241 ]
#  [0.18796396]
#  [0.56919503]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.3678038 ]
#  [0.8474499 ]
#  [0.48640072]
#  [0.04145122]
#  [0.99708974]
#  [0.9454205 ]
#  [0.5761719 ]
#  [0.20342481]
#  [0.2931466 ]
#  [0.974051  ]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.65287244]
#  [0.18939757]
#  [0.26867592]
#  [0.5403223 ]
#  [0.04393327]
#  [0.65546346]
#  [0.5655216 ]
#  [0.9251175 ]
#  [0.00161219]
#  [0.30082083]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.47917688]
#  [0.89312565]
#  [0.6039244 ]
#  [0.7721571 ]
#  [0.581056  ]
#  [0.23852193]
#  [0.5824684 ]
#  [0.86549556]
#  [0.60140574]
#  [0.66786003]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.44991016]
#  [0.35363662]
#  [0.5882293 ]
#  [0.47217917]
#  [0.53592384]
#  [0.9858947 ]
#  [0.9404267 ]
#  [0.6284368 ]
#  [0.7031697 ]
#  [0.05438936]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.65358233]
#  [0.70085776]
#  [0.63265455]
#  [0.8658421 ]
#  [0.7642329 ]
#  [0.5803355 ]
#  [0.6047349 ]
#  [0.33922887]
#  [0.5471413 ]
#  [0.6850797 ]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.9727261 ]
#  [0.95972   ]
#  [0.5582032 ]
#  [0.5020131 ]
#  [0.1826508 ]
#  [0.4291588 ]
#  [0.880378  ]
#  [0.80723083]
#  [0.6973531 ]
#  [0.2882576 ]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.7836131 ]
#  [0.6994804 ]
#  [0.18238282]
#  [0.13988054]
#  [0.22714972]
#  [0.23423731]
#  [0.97840655]
#  [0.407457  ]
#  [0.15735805]
#  [0.04685068]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.9774703 ]
#  [0.73826194]
#  [0.3575846 ]
#  [0.71170115]
#  [0.07405865]
#  [0.7978742 ]
#  [0.25773048]
#  [0.03192949]
#  [0.60863626]
#  [0.15605521]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.03979504]
#  [0.84713554]
#  [0.480011  ]
#  [0.54442406]
#  [0.99601555]
#  [0.23037803]
#  [0.7010287 ]
#  [0.5073575 ]
#  [0.2206111 ]
#  [0.7326232 ]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.11413717]
#  [0.553434  ]
#  [0.02898562]
#  [0.06493938]
#  [0.72072554]
#  [0.7953603 ]
#  [0.40659654]
#  [0.9540591 ]
#  [0.52440095]
#  [0.04973388]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.78298104]
#  [0.42775643]
#  [0.9311409 ]
#  [0.75240874]
#  [0.25064588]
#  [0.87831473]
#  [0.03354704]
#  [0.1431117 ]
#  [0.09609973]
#  [0.01339519]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.95261216]
#  [0.8528236 ]
#  [0.51685476]
#  [0.1928643 ]
#  [0.4725399 ]
#  [0.11591327]
#  [0.08053362]
#  [0.81552577]
#  [0.9031377 ]
#  [0.83166826]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.9680573 ]
#  [0.66406894]
#  [0.08815837]
#  [0.52224195]
#  [0.2634685 ]
#  [0.28872597]
#  [0.18515861]
#  [0.8545501 ]
#  [0.57512534]
#  [0.6536311 ]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.913942  ]
#  [0.4456879 ]
#  [0.34042215]
#  [0.5177282 ]
#  [0.15119767]
#  [0.98563504]
#  [0.06809986]
#  [0.6728209 ]
#  [0.07218766]
#  [0.8723613 ]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.529904  ]
#  [0.5444274 ]
#  [0.45584357]
#  [0.40225613]
#  [0.80232215]
#  [0.22366834]
#  [0.2701248 ]
#  [0.5635631 ]
#  [0.16025543]
#  [0.29545057]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.31054306]
#  [0.04179454]
#  [0.5002575 ]
#  [0.4715129 ]
#  [0.5707785 ]
#  [0.21001458]
#  [0.67229915]
#  [0.09922445]
#  [0.04526031]
#  [0.14175403]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.83989644]
#  [0.57596827]
#  [0.09056199]
#  [0.3550086 ]
#  [0.7352469 ]
#  [0.23686576]
#  [0.18335688]
#  [0.6157942 ]
#  [0.64408636]
#  [0.45336926]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.26254296]
#  [0.9056655 ]
#  [0.02172911]
#  [0.33988118]
#  [0.07041585]
#  [0.9406537 ]
#  [0.5734681 ]
#  [0.7015178 ]
#  [0.14647818]
#  [0.37064922]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.59642196]
#  [0.19835007]
#  [0.65848243]
#  [0.48270428]
#  [0.5928205 ]
#  [0.81330884]
#  [0.1468302 ]
#  [0.7055532 ]
#  [0.43445826]
#  [0.05986786]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.97973275]
#  [0.8230891 ]
#  [0.70798147]
#  [0.96832025]
#  [0.09668887]
#  [0.93960917]
#  [0.43327367]
#  [0.28732586]
#  [0.7666209 ]
#  [0.17878473]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.39428198]
#  [0.20306301]
#  [0.743991  ]
#  [0.8931365 ]
#  [0.31538844]
#  [0.7537539 ]
#  [0.07457173]
#  [0.78755546]
#  [0.9734951 ]
#  [0.47425902]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.04069483]
#  [0.9165671 ]
#  [0.15350771]
#  [0.81981075]
#  [0.77165127]
#  [0.16479921]
#  [0.18317854]
#  [0.08647907]
#  [0.3682233 ]
#  [0.8039267 ]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.59842885]
#  [0.80349827]
#  [0.70660627]
#  [0.72924304]
#  [0.3743794 ]
#  [0.11647081]
#  [0.96474624]
#  [0.85754573]
#  [0.6994426 ]
#  [0.87167   ]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.8990711 ]
#  [0.68822765]
#  [0.22468102]
#  [0.759349  ]
#  [0.33283246]
#  [0.8840425 ]
#  [0.45063603]
#  [0.07388341]
#  [0.91700757]
#  [0.3264172 ]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.85431874]
#  [0.55014336]
#  [0.46176696]
#  [0.44034934]
#  [0.24438   ]
#  [0.7369356 ]
#  [0.8771527 ]
#  [0.76802254]
#  [0.7779008 ]
#  [0.38463473]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.09147429]
#  [0.39575386]
#  [0.6021906 ]
#  [0.10827839]
#  [0.0300076 ]
#  [0.40040123]
#  [0.5106957 ]
#  [0.8391179 ]
#  [0.37744164]
#  [0.96319723]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.35828304]
#  [0.74572635]
#  [0.5283216 ]
#  [0.96046245]
#  [0.7954869 ]
#  [0.4683901 ]
#  [0.52830005]
#  [0.46300673]
#  [0.00921154]
#  [0.06204712]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.24127054]
#  [0.05455267]
#  [0.45052648]
#  [0.3951584 ]
#  [0.02704227]
#  [0.04185104]
#  [0.5071374 ]
#  [0.515635  ]
#  [0.21155679]
#  [0.9008975 ]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.14033353]
#  [0.06566226]
#  [0.17428958]
#  [0.819394  ]
#  [0.56600785]
#  [0.7238885 ]
#  [0.7290355 ]
#  [0.20176208]
#  [0.36253655]
#  [0.08852327]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.6950815 ]
#  [0.59155667]
#  [0.71113384]
#  [0.36808324]
#  [0.22000515]
#  [0.39775229]
#  [0.72036755]
#  [0.26099145]
#  [0.2713505 ]
#  [0.8589121 ]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.35333598]
#  [0.7637702 ]
#  [0.477713  ]
#  [0.02399755]
#  [0.28371012]
#  [0.97250426]
#  [0.29590094]
#  [0.48439634]
#  [0.6805005 ]
#  [0.24390829]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.9425745 ]
#  [0.07716703]
#  [0.21264744]
#  [0.0313189 ]
#  [0.5923964 ]
#  [0.81559324]
#  [0.9431777 ]
#  [0.08417082]
#  [0.5288689 ]
#  [0.93007886]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.07224298]
#  [0.17654026]
#  [0.7033237 ]
#  [0.4390509 ]
#  [0.53360057]
#  [0.66743696]
#  [0.44860363]
#  [0.83586586]
#  [0.7207047 ]
#  [0.52224755]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.7801198 ]
#  [0.16525865]
#  [0.35160506]
#  [0.74400806]
#  [0.28333783]
#  [0.96151197]
#  [0.9574983 ]
#  [0.603281  ]
#  [0.62056077]
#  [0.12913322]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.82561123]
#  [0.03180373]
#  [0.44621885]
#  [0.17768526]
#  [0.4313656 ]
#  [0.61149275]
#  [0.46895158]
#  [0.38723946]
#  [0.44397676]
#  [0.13361716]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.07410789]
#  [0.5354985 ]
#  [0.7974982 ]
#  [0.99079907]
#  [0.15688694]
#  [0.9780662 ]
#  [0.6502497 ]
#  [0.6120881 ]
#  [0.6948662 ]
#  [0.43976545]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.6305325 ]
#  [0.42721474]
#  [0.21142387]
#  [0.45682728]
#  [0.5300777 ]
#  [0.13097548]
#  [0.4927472 ]
#  [0.53259265]
#  [0.7169516 ]
#  [0.76956534]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.8790319 ]
#  [0.26213467]
#  [0.36850476]
#  [0.5735444 ]
#  [0.04854703]
#  [0.6964772 ]
#  [0.7246592 ]
#  [0.54586625]
#  [0.6798762 ]
#  [0.32263112]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.05250967]
#  [0.42827046]
#  [0.93382704]
#  [0.6565385 ]
#  [0.45701778]
#  [0.27427053]
#  [0.08915341]
#  [0.3620752 ]
#  [0.17943239]
#  [0.35299742]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.93355525]
#  [0.6730677 ]
#  [0.98149514]
#  [0.07549489]
#  [0.82836795]
#  [0.69118285]
#  [0.68085206]
#  [0.52224314]
#  [0.719677  ]
#  [0.9155233 ]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.732545  ]
#  [0.14815402]
#  [0.0807327 ]
#  [0.12065732]
#  [0.7762561 ]
#  [0.72443974]
#  [0.21361566]
#  [0.11537445]
#  [0.5359181 ]
#  [0.82052386]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.31798708]
#  [0.04708147]
#  [0.77424467]
#  [0.35691547]
#  [0.8347769 ]
#  [0.54714346]
#  [0.7820325 ]
#  [0.26824796]
#  [0.42178667]
#  [0.7633995 ]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.4740758 ]
#  [0.7717452 ]
#  [0.02491975]
#  [0.83433855]
#  [0.7960448 ]
#  [0.73769116]
#  [0.12856638]
#  [0.31079245]
#  [0.79988873]
#  [0.6157993 ]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.4159181 ]
#  [0.11695504]
#  [0.9083928 ]
#  [0.5466062 ]
#  [0.00595129]
#  [0.43722332]
#  [0.62362456]
#  [0.03906834]
#  [0.35226595]
#  [0.57742035]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.12731111]
#  [0.9126266 ]
#  [0.53318965]
#  [0.995801  ]
#  [0.695997  ]
#  [0.8449094 ]
#  [0.6800593 ]
#  [0.16597998]
#  [0.8277246 ]
#  [0.578506  ]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.6174749 ]
#  [0.6144799 ]
#  [0.09222317]
#  [0.6185851 ]
#  [0.4951297 ]
#  [0.23025882]
#  [0.2412914 ]
#  [0.35220373]
#  [0.35594654]
#  [0.8717109 ]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.3802073 ]
#  [0.05580521]
#  [0.5721595 ]
#  [0.29954672]
#  [0.29712915]
#  [0.4348085 ]
#  [0.49582827]
#  [0.76887953]
#  [0.02376461]
#  [0.15840149]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.6880902 ]
#  [0.49889672]
#  [0.92900705]
#  [0.8904817 ]
#  [0.91489244]
#  [0.6742984 ]
#  [0.29124367]
#  [0.9189329 ]
#  [0.9042697 ]
#  [0.32527244]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.9600562 ]
#  [0.9462373 ]
#  [0.25536585]
#  [0.431149  ]
#  [0.19128609]
#  [0.06069553]
#  [0.3485285 ]
#  [0.3631767 ]
#  [0.28454435]
#  [0.16622019]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.3214507 ]
#  [0.5329633 ]
#  [0.55136037]
#  [0.76271164]
#  [0.43861282]
#  [0.43439722]
#  [0.6278498 ]
#  [0.9037286 ]
#  [0.43417656]
#  [0.43874002]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.23501492]
#  [0.7174102 ]
#  [0.01783311]
#  [0.717819  ]
#  [0.8025985 ]
#  [0.35081375]
#  [0.6941855 ]
#  [0.89421713]
#  [0.7117598 ]
#  [0.77733994]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.31864476]
#  [0.3509599 ]
#  [0.5260198 ]
#  [0.02899468]
#  [0.93985784]
#  [0.12548637]
#  [0.43148053]
#  [0.07545471]
#  [0.28271317]
#  [0.15985084]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.31627965]
#  [0.761075  ]
#  [0.63882875]
#  [0.25439906]
#  [0.10241175]
#  [0.2798282 ]
#  [0.00482595]
#  [0.5213225 ]
#  [0.8000388 ]
#  [0.88987076]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.9118384 ]
#  [0.03089643]
#  [0.30036438]
#  [0.5083536 ]
#  [0.1047107 ]
#  [0.81868184]
#  [0.61642694]
#  [0.53642106]
#  [0.22455525]
#  [0.76197433]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.55449843]
#  [0.29995573]
#  [0.276523  ]
#  [0.7354492 ]
#  [0.42821836]
#  [0.9366585 ]
#  [0.17660475]
#  [0.16066766]
#  [0.7188411 ]
#  [0.4341433 ]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.27724516]
#  [0.9762006 ]
#  [0.45590615]
#  [0.7837111 ]
#  [0.5745902 ]
#  [0.35671556]
#  [0.3987323 ]
#  [0.89984035]
#  [0.63931346]
#  [0.57114613]], shape=(10, 1), dtype=float32)
# tf.Tensor(
# [[0.69623196]
#  [0.2796142 ]
#  [0.23365104]
#  [0.87445295]
#  [0.9322214 ]
#  [0.8611696 ]
#  [0.4134053 ]
#  [0.19887578]
#  [0.7210126 ]
#  [0.13438547]], shape=(10, 1), dtype=float32)

# %% [markdown]
# #### When datasets are very large (the typical case), they might not fit into any memory (CPU or GPU). To load the large datasets, TFRecord files can be used.
